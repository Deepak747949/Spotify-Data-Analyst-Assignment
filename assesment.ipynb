# %% [markdown]
# # 🎵 Spotify Artist Catalog & Unclaimed Musical Works Cross-Reference
#
# ## Project Overview
#
# This project demonstrates working with APIs, large datasets, and memory-efficient processing to solve a real-world music data challenge.
#
# ## Goals
#
# 1. **Retrieve Spotify Artist Catalog:**
#    - Use the Spotify API to fetch a complete catalog of a chosen artist.
#    - Include all albums, singles, EPs, and tracks.
#
# 2. **Export Catalog with Details:**
#    - Track name, album name, release date, and ISRC codes.
#    - Handle API rate limits safely to avoid request failures.
#
# 3. **Cross-Reference with Large Dataset:**
#    - Compare artist ISRCs against the unclaimed works dataset (`unclaimedmusicalworkrightshares.tsv`).
#    - Use memory-efficient chunked processing to handle 7GB TSV files.
#
# 4. **Generate Organized Excel Report:**
#    - Sheet 1: Full Artist Catalog.
#    - Sheet 2: Matches found in unclaimed dataset.
#    - Sheet 3: Notes and process details.
#
# ## Highlights
#
# - **API Integration:** Spotify Web API used for reliable data retrieval.
# - **Memory-Efficient Processing:** Large TSV processed in chunks to avoid memory overflow.
# - **Data Matching:** ISRC codes cleaned and standardized to ensure accurate cross-referencing.
# - **Output:** Clean, structured Excel workbook summarizing artist tracks and unclaimed works matches.

# %%
import pandas as pd
file_path = "C:/Users/deepa/Placement_Assesment/data/assessment.tsv"
df0 = pd.read_csv(file_path, sep='\t', nrows=0)
df0.columns.tolist()
# Out:
# ['#UnclaimedMusicalWorkRightShareRecordId',
#  'ResourceRecordId',
#  'MusicalWorkRecordId',
#  'ISRC',
#  'DspResourceId',
#  'ResourceTitle',
#  'ResourceSubTitle',
#  'AlternativeResourceTitle',
#  'DisplayArtistName',
#  'DisplayArtistISNI',
#  'Duration',
#  'UnclaimedRightSharePercentage',
#  'PercentileForPrioritisation']

# %%
sample = pd.read_csv(file_path, sep='\t', nrows=5)
sample
# Out:
#    #UnclaimedMusicalWorkRightShareRecordId  ResourceRecordId  \
# 0                                 10257123   45_Tra.56132724
# 1                                 10257141  45_Tra.356056553
# 2                                 10257164  45_Tra.224697054
# 3                                 10257193  45_Tra.644624494
# 4                                 10257198  45_Tra.790295191
#
#   MusicalWorkRecordId          ISRC            DspResourceId  \
# 0              W0963A  USCM50300149   melodyvr::Tra.56132724
# 1              HA3LHN  GBKQU1876813  melodyvr::Tra.356056553
# 2              AV957Y  BEK011600042  melodyvr::Tra.224697054
# 3              TVCOAI  US2642149111  melodyvr::Tra.644624494
# 4              PI72QT  USLD91751743  melodyvr::Tra.790295191
#
#                      ResourceTitle  ResourceSubTitle  \
# 0                     WE CAN SMOKE               NaN
# 1                     HIGH ROLLERS               NaN
# 2                           ARCADE               NaN
# 3           THE SCREAMS (2022 MIX)               NaN
# 4  PAY ATTENTION (FEAT. D- STYLES)               NaN
#
#    AlternativeResourceTitle          DisplayArtistName  DisplayArtistISNI  \
# 0                       NaN                 BIG TYMERS                NaN
# 1                       NaN               ALCOSTA BLVD                NaN
# 2                       NaN  DIMITRI VEGAS & LIKE MIKE                NaN
# 3                       NaN                  INTEGRITY                NaN
# 4                       NaN                  LEE SCOTT                NaN
#
#    Duration  UnclaimedRightSharePercentage  PercentileForPrioritisation
# 0       348                           12.5                          NaN
# 1       244                           50.0                          NaN
# 2       285                           25.0                          NaN
# 3       175                           50.0                          NaN
# 4       135                           50.0                          NaN

# %%
# counting total rows in the dataset
import csv
with open(file_path, 'r', encoding='utf-8') as f:
    row_count = sum(1 for _ in f) - 1  # minus header
print("Total rows:", row_count)
# Out:
# Total rows: 59989690

# %%
#checking some random rows
sample_rows = pd.read_csv(file_path, sep='\t', skiprows=lambda i: i>0 and i%100000!=0, nrows=200, dtype=str)
sample_rows.head()
# Out:
#   #UnclaimedMusicalWorkRightShareRecordId  \
# 0                                50201102
# 1                                10118026
# 2                                50184491
# 3                                10036547
# 4                                14289810
#
#                          ResourceRecordId MusicalWorkRecordId          ISRC  \
# 0  2_spotify:track:2jmaDR4LMXvOSVwkFt9YJj              GV8JYQ  DEW871503411
# 1                           22_1790766085              BD6XKY  USUYG1580417
# 2  2_spotify:track:2IiCxBFyfsJnjqqFW6zfIN              M1841L  USTV10300135
# 3                          15_dQKelpy1-pY              L8430Y  USAR30100183
# 4                                22_52456              S28348  USPR39882290
#
#                                    DspResourceId ResourceTitle  \
# 0  spotify::spotify:track:2jmaDR4LMXvOSVwkFt9YJj    GOOD TIMES
# 1                         applemusic::1790766085          AMMO
# 2  spotify::spotify:track:2IiCxBFyfsJnjqqFW6zfIN   MADE TO LIE
# 3                           youtube::dQKelpy1-pY  LIVE FOR YOU
# 4                              applemusic::52456     6/8 - 7/8
#
#   ResourceSubTitle AlternativeResourceTitle DisplayArtistName  \
# 0              NaN                      NaN         NEV SCOTT
# 1              NaN                      NaN   SHORDIE SHORDIE
# 2              NaN                      NaN           DEFAULT
# 3              NaN                      NaN  BIG TENT REVIVAL
# 4              NaN                      NaN   THE HEADHUNTERS
#
#   DisplayArtistISNI Duration UnclaimedRightSharePercentage  \
# 0               NaN      403                          10.0
# 1               NaN      184                          25.0
# 2               NaN      195                          20.0
# 3               NaN      397                          50.0
# 4               NaN      416                          60.0
#
#   PercentileForPrioritisation
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %% [markdown]
# ## Sample Rows from Large TSV
#
# **Purpose:** Preview dataset without loading full 7GB file.
#
# **Method:**
# - Read file in chunks (`chunksize=200k`).
# - Randomly sample 5 rows per chunk.
# - Combine samples (~50 rows total) for inspection.
#
# **Benefit:** Efficient memory usage, quick dataset overview.

# %%
samples = []
chunksize = 200000
for chunk in pd.read_csv(file_path, sep='\t', chunksize=chunksize, dtype=str):
    samples.append(chunk.sample(n=min(5, len(chunk)), random_state=1))
    if len(samples) >= 10:  # ~50 rows total
        break
sample_df = pd.concat(samples, ignore_index=True)
sample_df.head()
# Out:
#   #UnclaimedMusicalWorkRightShareRecordId     ResourceRecordId  \
# 0                                 4545468          25_38297084
# 1                                 9996431  15_A177162882979847
# 2                                10421181         13_113785362
# 3                                14412903         30_263306959
# 4                                14370340          27_94603049
#
#   MusicalWorkRecordId          ISRC              DspResourceId  \
# 0              Z5926M  TCACK1568791      iheartradio::38297084
# 1              S8055I  DEA450303930  youtube::A177162882979847
# 2              SVDN8N  DEU601506025          deezer::113785362
# 3              W4715M  HKUM71000579           tidal::263306959
# 4              BC3QF0  QZDA52072030          pandora::94603049
#
#                         ResourceTitle ResourceSubTitle  \
# 0  MI CHICA ESTA LOCA (FEAT. PITBULL)              NaN
# 1                        SAILING AWAY              NaN
# 2                        SHINING STAR              NaN
# 3                                完美孤独              NaN
# 4        BABY DRIVER (FEAT. A$AP ANT)              NaN
#
#   AlternativeResourceTitle DisplayArtistName DisplayArtistISNI Duration  \
# 0                      NaN       MATT HUNTER               NaN       40
# 1                      NaN    AXEL RUDI PELL               NaN      351
# 2                      NaN  RHAPSODY OF FIRE               NaN      279
# 3                      NaN               莫文蔚               NaN      291
# 4                      NaN      A$AP TWELVYY               NaN      125
#
#   UnclaimedRightSharePercentage PercentileForPrioritisation
# 0                         14.31                         NaN
# 1                          40.0                         NaN
# 2                         12.93                         NaN
# 3                          50.0                         NaN
# 4                          75.0                         NaN

# %%
# Getting the unique ISRC from our dataset
import duckdb

con = duckdb.connect()
query = """
SELECT DISTINCT NULLIF(trim(upper(regexp_replace(ISRC, '-', ''))), '') AS isrc
FROM read_csv_auto('C:/Users/deepa/Placement_Assesment/data/assessment.tsv', delim='\t', header=True)
WHERE ISRC IS NOT NULL
"""
unique_isrc_df = con.execute(query).df()
unique_isrc_df.to_csv('unique_isrcs_from_tsv.csv', index=False)
print("Unique ISRC count:", len(unique_isrc_df))
# Out:
# Unique ISRC count: 10487372

# %%
import os, time
import pandas as pd
from spotipy import Spotify
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.exceptions import SpotifyException
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Initialize Spotify API
# - Load environment variables for `SPOTIPY_CLIENT_ID` and `SPOTIPY_CLIENT_SECRET`.
# - Initialize the Spotify API client.
# - Define a safe Spotify call function to handle rate limits automatically.

# %%
# Initialize Spotify API
sp = Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id=os.getenv('SPOTIPY_CLIENT_ID'),
        client_secret=os.getenv('SPOTIPY_CLIENT_SECRET')
    ),
    requests_timeout=30
)

# %%
# Safe Spotify call with automatic rate-limit handling
def safe_spotify_call(func, *args, **kwargs):
    while True:
        try:
            return func(*args, **kwargs)
        except SpotifyException as e:
            if e.http_status == 429:  # rate limit
                retry_after = int(e.headers.get('Retry-After', '5'))
                print(f"Rate limit hit. Waiting {retry_after} seconds...")
                time.sleep(retry_after + 1)
            else:
                raise e
        except Exception as e:
            print("Spotify call error:", e)
            time.sleep(5)

# %% [markdown]
# ## **Fetch Artist Catalog**
#
# - Retrieve artist ID using Spotify search API.
# - Fetch all albums and singles of the artist.
# - Retrieve tracks from each album.
# - Collect ISRC codes for all tracks.
# - Store results in a DataFrame with relevant columns.

# %%
# Functions using safe_spotify_call
def get_artist_id(name):
    res = safe_spotify_call(sp.search, q=f'artist:{name}', type='artist', limit=1)
    items = res.get('artists', {}).get('items', [])
    if not items:
        raise ValueError("Artist not found")
    return items[0]['id']

def fetch_all_albums(artist_id):
    albums = []
    results = safe_spotify_call(sp.artist_albums, artist_id, album_type='album,single,compilation,appears_on', limit=50)
    albums.extend(results['items'])
    while results.get('next'):
        results = safe_spotify_call(sp.next, results)
        albums.extend(results['items'])
    albums = list({a['id']: a for a in albums}.values())
    print(f"Total albums fetched: {len(albums)}")
    return albums

def fetch_tracks_for_album(album, album_index=None, total_albums=None):
    results = safe_spotify_call(sp.album_tracks, album['id'], limit=50)
    tracks = results['items']
    while results.get('next'):
        results = safe_spotify_call(sp.next, results)
        tracks.extend(results['items'])
    if album_index is not None:
        print(f"Fetched {len(tracks)} tracks from album {album_index+1}/{total_albums}: {album['name']}")
    return [{'track_id': t['id'], 'track_name': t['name'], 
             'album_id': album['id'], 'album_name': album['name'], 
             'release_date': album.get('release_date')} for t in tracks]

def fetch_isrc_for_tracks(tracks_df):
    ids = tracks_df['track_id'].dropna().unique().tolist()
    isrc_map = {}
    total_batches = (len(ids) + 49) // 50
    for i in range(0, len(ids), 50):
        batch_num = (i // 50) + 1
        batch = ids[i:i+50]
        recs = safe_spotify_call(sp.tracks, batch)['tracks']
        for r in recs:
            if r is None: continue
            isrc_map[r['id']] = r.get('external_ids', {}).get('isrc')
        print(f"Processed batch {batch_num}/{total_batches} of track ISRCs")
        time.sleep(0.1)
    tracks_df['isrc'] = tracks_df['track_id'].map(isrc_map)
    tracks_df['isrc'] = tracks_df['isrc'].astype(str).str.upper().str.strip().str.replace('-', '', regex=False)
    tracks_df.loc[tracks_df['isrc'] == 'None', 'isrc'] = None
    return tracks_df.drop_duplicates(subset=['isrc', 'track_id'])

# %%
# Build full catalog
def build_artist_catalog(artist_name):
    artist_id = get_artist_id(artist_name)
    albums = fetch_all_albums(artist_id)
    all_tracks = []
    total_albums = len(albums)
    for idx, album in enumerate(albums):
        all_tracks.extend(fetch_tracks_for_album(album, album_index=idx, total_albums=total_albums))
    df = pd.DataFrame(all_tracks).drop_duplicates(subset=['track_id'])
    df = fetch_isrc_for_tracks(df)
    return df[['track_name', 'album_name', 'release_date', 'track_id', 'isrc']]

# %%
# Example usage 
artist_name = "Coldplay"
artist_df = build_artist_catalog(artist_name)
artist_df.to_csv('artist_catalog_with_isrcs.csv', index=False)
print("Tracks fetched:", len(artist_df))
# Out:
# Total albums fetched: 1684
# Fetched 10 tracks from album 1/1684: Moon Music
# Fetched 20 tracks from album 2/1684: Moon Music (Full Moon Edition)
# Fetched 12 tracks from album 3/1684: Music Of The Spheres
# Fetched 16 tracks from album 4/1684: Everyday Life
# Fetched 24 tracks from album 5/1684: Live in Buenos Aires
# Fetched 11 tracks from album 6/1684: A Head Full of Dreams
# Fetched 9 tracks from album 7/1684: Ghost Stories Live 2014
# Fetched 9 tracks from album 8/1684: Ghost Stories
# Fetched 15 tracks from album 9/1684: Live 2012
# Fetched 14 tracks from album 10/1684: Mylo Xyloto
# Fetched 9 tracks from album 11/1684: LeftRightLeftRightLeft (Live)
# Fetched 18 tracks from album 12/1684: Viva La Vida (Prospekt's March Edition)
# Fetched 10 tracks from album 13/1684: Viva La Vida or Death and All His Friends
# Fetched 13 tracks from album 14/1684: X&Y
# Fetched 12 tracks from album 15/1684: Live 2003
# Fetched 11 tracks from album 16/1684: A Rush of Blood to the Head
# Fetched 10 tracks from album 17/1684: Parachutes
# Fetched 3 tracks from album 18/1684: ALL MY LOVE
# Fetched 1 tracks from album 19/1684: WE PRAY (TWICE Version)
# Fetched 2 tracks from album 20/1684: Ma Meilleure Ennemie ft. Coldplay
# Fetched 1 tracks from album 21/1684: WE PRAY (Jasleen Royal Version)
# Fetched 1 tracks from album 22/1684: ALL MY LOVE (PNAU x Coldplay)
# Fetched 3 tracks from album 23/1684: WE PRAY (Elyanna Version)
# Fetched 2 tracks from album 24/1684: WE PRAY (TINI Version)
# Fetched 1 tracks from album 25/1684: WE PRAY
# Fetched 1 tracks from album 26/1684: feelslikeimfallinginlove (Zerb x Coldplay)
# Fetched 1 tracks from album 27/1684: feelslikeimfallinginlove
# Fetched 1 tracks from album 28/1684: Biutyful
# Fetched 1 tracks from album 29/1684: Let Somebody Go (Ofenbach Remix)
# Fetched 4 tracks from album 30/1684: Let Somebody Go (Piano Version)
# Fetched 3 tracks from album 31/1684: Let Somebody Go (Kygo Remix)
# Fetched 2 tracks from album 32/1684: Let Somebody Go
# Fetched 2 tracks from album 33/1684: Spotify Singles
# Fetched 1 tracks from album 34/1684: My Universe (David Guetta Remix)
# Fetched 1 tracks from album 35/1684: My Universe (Galantis Remix)
# Fetched 3 tracks from album 36/1684: My Universe
# Fetched 1 tracks from album 37/1684: My Universe (SUGA's Remix)
# Fetched 2 tracks from album 38/1684: My Universe
# Fetched 1 tracks from album 39/1684: Coloratura
# Fetched 1 tracks from album 40/1684: Overtura
# Fetched 2 tracks from album 41/1684: Higher Power (Alyx Ander Remix)
# Fetched 2 tracks from album 42/1684: Higher Power (Acoustic Version)
# Fetched 1 tracks from album 43/1684: Higher Power (Tiësto Remix)
# Fetched 1 tracks from album 44/1684: Higher Power (ZHU Remix)
# Fetched 1 tracks from album 45/1684: Higher Power
# Fetched 1 tracks from album 46/1684: Flags
# Fetched 1 tracks from album 47/1684: Champion Of The World (Live at NPR's Tiny Desk)
# Fetched 5 tracks from album 48/1684: Champion of The World / Daddy
# Fetched 1 tracks from album 49/1684: Orphans (Muzi Remix)
# Fetched 3 tracks from album 50/1684: Everyday Life
# Fetched 2 tracks from album 51/1684: Orphans / Arabesque
# Fetched 1 tracks from album 52/1684: A Head Full of Dreams (Live in Buenos Aires)
# Fetched 1 tracks from album 53/1684: Fix You (Live in Buenos Aires)
# Fetched 1 tracks from album 54/1684: Viva La Vida (Live in Buenos Aires)
# Fetched 1 tracks from album 55/1684: A L I E N S (Markus Dravs Remix)
# Fetched 5 tracks from album 56/1684: Kaleidoscope EP
# Fetched 1 tracks from album 57/1684: A L I E N S
# Fetched 1 tracks from album 58/1684: Something Just Like This (Tokyo Remix)
# Fetched 1 tracks from album 59/1684: All I Can Think About Is You
# Fetched 6 tracks from album 60/1684: Something Just Like This (Remixes)
# Fetched 1 tracks from album 61/1684: Hypnotised
# Fetched 1 tracks from album 62/1684: Something Just Like This
# Fetched 5 tracks from album 63/1684: Live from Spotify London
# Fetched 2 tracks from album 64/1684: Everglow
# Fetched 1 tracks from album 65/1684: Up&Up (Freedo Remix)
# Fetched 1 tracks from album 66/1684: Up&Up
# Fetched 1 tracks from album 67/1684: Adventure of a Lifetime (Yotto Remix)
# Fetched 1 tracks from album 68/1684: Hymn for the Weekend (Seeb Remix)
# Fetched 1 tracks from album 69/1684: Adventure of a Lifetime (Matoma Remix)
# Fetched 1 tracks from album 70/1684: Everglow
# Fetched 1 tracks from album 71/1684: Adventure of a Lifetime
# Fetched 1 tracks from album 72/1684: True Love (Davide Rossi Remix)
# Fetched 1 tracks from album 73/1684: A Sky Full of Stars (Hardwell Remix)
# Fetched 1 tracks from album 74/1684: Ink (Live at Le Casino De Paris, Paris)
# Fetched 1 tracks from album 75/1684: True Love
# Fetched 1 tracks from album 76/1684: A Sky Full of Stars (Robin Schulz Remix)
# Fetched 1 tracks from album 77/1684: Wish I Was Here
# Fetched 4 tracks from album 78/1684: A Sky Full of Stars
# Fetched 1 tracks from album 79/1684: Midnight (Kygo Remix)
# Fetched 4 tracks from album 80/1684: Midnight (Remixes)
# Fetched 1 tracks from album 81/1684: A Sky Full of Stars
# Fetched 1 tracks from album 82/1684: Midnight
# Fetched 1 tracks from album 83/1684: Magic
# Fetched 1 tracks from album 84/1684: Atlas (From “The Hunger Games: Catching Fire” Soundtrack)
# Fetched 1 tracks from album 85/1684: Princess of China (Andre Sobota Remix)
# Fetched 4 tracks from album 86/1684: Princess of China
# Fetched 1 tracks from album 87/1684: Charlie Brown
# Fetched 1 tracks from album 88/1684: Charlie Brown (Dave Audé Remix)
# Fetched 1 tracks from album 89/1684: Hurts Like Heaven
# Fetched 1 tracks from album 90/1684: Paradise
# Fetched 3 tracks from album 91/1684: Every Teardrop Is a Waterfall
# Fetched 1 tracks from album 92/1684: Every Teardrop Is a Waterfall
# Fetched 1 tracks from album 93/1684: Christmas Lights
# Fetched 1 tracks from album 94/1684: Strawberry Swing
# Fetched 3 tracks from album 95/1684: Life in Technicolor ii
# Fetched 4 tracks from album 96/1684: Lost!
# Fetched 2 tracks from album 97/1684: Viva La Vida
# Fetched 8 tracks from album 98/1684: Prospekt's March
# Fetched 2 tracks from album 99/1684: Violet Hill
# Fetched 2 tracks from album 100/1684: The Hardest Part
# Fetched 3 tracks from album 101/1684: Talk
# Fetched 3 tracks from album 102/1684: Talk
# Fetched 3 tracks from album 103/1684: Fix You
# Fetched 1 tracks from album 104/1684: Fix You
# Fetched 3 tracks from album 105/1684: Speed of Sound
# Fetched 1 tracks from album 106/1684: Speed of Sound
# Fetched 1 tracks from album 107/1684: 2000 Miles
# Fetched 1 tracks from album 108/1684: Clocks (Royksopp Trembling Heart Mix)
# Fetched 2 tracks from album 109/1684: God Put a Smile upon Your Face
# Fetched 2 tracks from album 110/1684: Clocks
# Fetched 3 tracks from album 111/1684: Clocks
# Fetched 1 tracks from album 112/1684: Murder
# Fetched 3 tracks from album 113/1684: The Scientist
# Fetched 3 tracks from album 114/1684: In My Place
# Fetched 1 tracks from album 115/1684: Have Yourself a Merry Little Christmas (Jo Whiley, BBC Radio 1 Session)
# Fetched 2 tracks from album 116/1684: Don't Panic
# Fetched 3 tracks from album 117/1684: Trouble
# Fetched 3 tracks from album 118/1684: Yellow
# Fetched 3 tracks from album 119/1684: Shiver
# Fetched 5 tracks from album 120/1684: The Blue Room
# Fetched 3 tracks from album 121/1684: Brothers & Sisters
# Fetched 55 tracks from album 122/1684: New Hits Heat Check
# Fetched 30 tracks from album 123/1684: Girls' Night Out
# Fetched 30 tracks from album 124/1684: Top Hits 2010-2020
# Fetched 63 tracks from album 125/1684: The Best Songs of All Time - Greatest Hits
# Fetched 100 tracks from album 126/1684: 100 Greatest Motivation Songs
# Fetched 39 tracks from album 127/1684: Summer Beach Days
# Fetched 25 tracks from album 128/1684: THE BEST EVER: Acoustic
# Fetched 40 tracks from album 129/1684: So Am I - 10's Anthems
# Fetched 100 tracks from album 130/1684: 100 Greatest Love Songs
# Fetched 17 tracks from album 131/1684: Hot Hot Hits
# Fetched 31 tracks from album 132/1684: Musica che ti fa emozionare
# Fetched 30 tracks from album 133/1684: Music for a Classroom
# Fetched 50 tracks from album 134/1684: Pop - Top Shelf
# Fetched 48 tracks from album 135/1684: Músicas Internacionais para Lojas 2024
# Fetched 26 tracks from album 136/1684: Músicas Existenciais
# Fetched 60 tracks from album 137/1684: Halloween Hits
# Fetched 97 tracks from album 138/1684: Greatest Hits Ever
# Fetched 50 tracks from album 139/1684: 10s Pop
# Fetched 39 tracks from album 140/1684: As Melhores do Rock Internacional e Nacional
# Fetched 48 tracks from album 141/1684: Life Sucks
# Fetched 45 tracks from album 142/1684: se acabaron las vacaciones
# Fetched 49 tracks from album 143/1684: Hits Noviembre 2023
# Fetched 100 tracks from album 144/1684: 100 Greatest Dinner Party Songs
# Fetched 60 tracks from album 145/1684: 10's UK Hits
# Fetched 28 tracks from album 146/1684: Holiday Songs
# Fetched 40 tracks from album 147/1684: In the End - 00's Rock
# Fetched 40 tracks from album 148/1684: Proulx Lake Fishing Songs
# Fetched 54 tracks from album 149/1684: 2010s Mixtape: The Greatest Hits
# Fetched 100 tracks from album 150/1684: 100 Greatest 2020 Songs
# Fetched 31 tracks from album 151/1684: Champions 2023
# Fetched 75 tracks from album 152/1684: 10's - Best of the Decade
# Fetched 50 tracks from album 153/1684: Shiny New Pop
# Fetched 35 tracks from album 154/1684: ...alone and/or lonely
# Fetched 60 tracks from album 155/1684: Forever Rock
# Fetched 36 tracks from album 156/1684: FALL IN LOVE 2025
# Fetched 25 tracks from album 157/1684: I Love It - Pop Anthems
# Fetched 47 tracks from album 158/1684: Músicas Internacionais para Lojas 2025
# Fetched 40 tracks from album 159/1684: July Vibes
# Fetched 22 tracks from album 160/1684: Fiesta de la Nieve
# Fetched 33 tracks from album 161/1684: Trailrunning - Ultrarunning Focus
# Fetched 54 tracks from album 162/1684: Acoustic: The Collection
# Fetched 40 tracks from album 163/1684: Le canzoni che ci hanno fatto innamorare
# Fetched 72 tracks from album 164/1684: No quiero regresar a clases
# Fetched 35 tracks from album 165/1684: i'm doing better, i made it to september
# Fetched 50 tracks from album 166/1684: Songs for the Car
# Fetched 40 tracks from album 167/1684: Popowe hymny
# Fetched 39 tracks from album 168/1684: Happy
# Fetched 38 tracks from album 169/1684: sad songs compilation: crying myself to sleep
# Fetched 47 tracks from album 170/1684: Dinner Party Anthems
# Fetched 95 tracks from album 171/1684: Guitar Heroes
# Fetched 45 tracks from album 172/1684: Salon Music 2025
# Fetched 49 tracks from album 173/1684: De regreso al amor
# Fetched 65 tracks from album 174/1684: Dance Monkey - 10's All Out
# Fetched 39 tracks from album 175/1684: booktok songs
# Fetched 29 tracks from album 176/1684: Passeggiata in centro 2024
# Fetched 49 tracks from album 177/1684: pop music just hits
# Fetched 51 tracks from album 178/1684: Apéro entre amis
# Fetched 50 tracks from album 179/1684: Songs to Belt in the Car
# Fetched 50 tracks from album 180/1684: Letní hity 2024
# Fetched 50 tracks from album 181/1684: Platinum Pop
# Fetched 75 tracks from album 182/1684: Hit Rewind
# Fetched 41 tracks from album 183/1684: Workday Songs - Office Music
# Fetched 42 tracks from album 184/1684: Romantic Songs
# Fetched 60 tracks from album 185/1684: 20s Soft Pop
# Fetched 37 tracks from album 186/1684: Just Hits
# Fetched 35 tracks from album 187/1684: Maldivas
# Fetched 35 tracks from album 188/1684: Jesienny Spacer
# Fetched 21 tracks from album 189/1684: Extended Prayer
# Fetched 22 tracks from album 190/1684: Summer 2014
# Fetched 66 tracks from album 191/1684: Top canciones de San Valentín
# Fetched 53 tracks from album 192/1684: Study Mode | Focus
# Fetched 21 tracks from album 193/1684: New Years Hits!
# Fetched 59 tracks from album 194/1684: Salida con mi casi algo
# Fetched 16 tracks from album 195/1684: Club Life: Vol. Two Miami
# Fetched 45 tracks from album 196/1684: Vamos que se puede
# Fetched 79 tracks from album 197/1684: Estar Living
# Fetched 28 tracks from album 198/1684: Vibra y Baila el Verano 2025
# Fetched 32 tracks from album 199/1684: Meu Pai é do ROCK
# Fetched 31 tracks from album 200/1684: just broke up
# Fetched 30 tracks from album 201/1684: Old Money It Girl
# Fetched 32 tracks from album 202/1684: Zonnige Dag
# Fetched 5 tracks from album 203/1684: Feel the Magic in the Air
# Fetched 100 tracks from album 204/1684: Summer 2025 - 100 Top Songs
# Fetched 41 tracks from album 205/1684: Timeless Party - Dance - Top Hits
# Fetched 36 tracks from album 206/1684: Con todo joven
# Fetched 50 tracks from album 207/1684: 20's Love Songs
# Fetched 40 tracks from album 208/1684: Música para tienda
# Fetched 57 tracks from album 209/1684: Summer Hits on Repeat
# Fetched 39 tracks from album 210/1684: Happy Songs
# Fetched 20 tracks from album 211/1684: Esenciales en inglés
# Fetched 42 tracks from album 212/1684: POP BEST HITS 2010s
# Fetched 100 tracks from album 213/1684: Pop Hits 2000 - 2024 - 100 Best Songs
# Fetched 75 tracks from album 214/1684: The Hits 10s
# Fetched 64 tracks from album 215/1684: classroom songs clean
# Fetched 100 tracks from album 216/1684: 100 Greatest Soft Rock Anthems Ever..
# Fetched 60 tracks from album 217/1684: Classroom Music Clean
# Fetched 50 tracks from album 218/1684: Top Songs - Hits 2025
# Fetched 50 tracks from album 219/1684: AUTUMN VIBES
# Fetched 42 tracks from album 220/1684: Biggest Tracks of the Year (2020 Hits)
# Fetched 30 tracks from album 221/1684: Retro Trending
# Fetched 40 tracks from album 222/1684: Coffeehouse Chill
# Fetched 30 tracks from album 223/1684: Sunset Sounds
# Fetched 49 tracks from album 224/1684: Pop en Ingles 2025
# Fetched 28 tracks from album 225/1684: Goodbye Everybody
# Fetched 37 tracks from album 226/1684: Classroom Pop Clean Hits
# Fetched 23 tracks from album 227/1684: Music of the Galaxy
# Fetched 86 tracks from album 228/1684: Highway Songs - cruising and relaxed driving
# Fetched 18 tracks from album 229/1684: Klavier - Pop Piano
# Fetched 50 tracks from album 230/1684: Home Office 2022
# Fetched 50 tracks from album 231/1684: Sommerhits 2025
# Fetched 58 tracks from album 232/1684: Hits - Greatest Evergreens
# Fetched 60 tracks from album 233/1684: We Are Young - 10's Best
# Fetched 60 tracks from album 234/1684: Belting Songs
# Fetched 50 tracks from album 235/1684: Pop On!
# Fetched 30 tracks from album 236/1684: Indie & Alternative 00's
# Fetched 30 tracks from album 237/1684: Totally Feelgood
# Fetched 50 tracks from album 238/1684: Perfect Love Songs
# Fetched 95 tracks from album 239/1684: Kürmusik
# Fetched 47 tracks from album 240/1684: Músicas de Casamento: Pop Rock
# Fetched 55 tracks from album 241/1684: All Out Alternative
# Fetched 100 tracks from album 242/1684: 100 Most Uplifting Songs Ever
# Fetched 34 tracks from album 243/1684: Soft Pop Hits
# Fetched 50 tracks from album 244/1684: Some Great Pop
# Fetched 20 tracks from album 245/1684: Top June 2025
# Fetched 22 tracks from album 246/1684: Best 00s Pop Ever
# Fetched 35 tracks from album 247/1684: Lounge Music 2025
# Fetched 39 tracks from album 248/1684: Top Best Songs of 2024
# Fetched 48 tracks from album 249/1684: Timeless Songs
# Fetched 20 tracks from album 250/1684: Friday night reminisce
# Fetched 44 tracks from album 251/1684: Hits Junio 2024
# Fetched 53 tracks from album 252/1684: Indie Summer Drinking Songs
# Fetched 64 tracks from album 253/1684: A Sky Full of Stars - Modern Pop
# Fetched 42 tracks from album 254/1684: Hit Wave
# Fetched 80 tracks from album 255/1684: New Years Eve Party At Home
# Fetched 44 tracks from album 256/1684: Musica per la barca - Hit estate 2024
# Fetched 35 tracks from album 257/1684: Billion Stream Hits
# Fetched 50 tracks from album 258/1684: It's a TikTok Thing
# Fetched 50 tracks from album 259/1684: Indie Bangers 50 Great Alternatives
# Fetched 100 tracks from album 260/1684: 100 from the 10's - Rock
# Fetched 37 tracks from album 261/1684: diulang lagi
# Fetched 65 tracks from album 262/1684: 00's Flashback
# Fetched 45 tracks from album 263/1684: Soft & Easy Pop Hits
# Fetched 50 tracks from album 264/1684: All Night Dance Motion
# Fetched 45 tracks from album 265/1684: TOP HITS 2024
# Fetched 25 tracks from album 266/1684: Downtempo Classics
# Fetched 26 tracks from album 267/1684: Bienvenido otoño
# Fetched 38 tracks from album 268/1684: Trending Songs 2025
# Fetched 37 tracks from album 269/1684: Twenty Tens Easy
# Fetched 30 tracks from album 270/1684: Hits 2000
# Fetched 46 tracks from album 271/1684: Eclettica Italiana
# Fetched 60 tracks from album 272/1684: 00's Hits Massive Bangers
# Fetched 34 tracks from album 273/1684: Summer Morning
# Fetched 35 tracks from album 274/1684: Lagu Melow
# Fetched 71 tracks from album 275/1684: Radio Hits - Die 80er 90er 2000er und das Beste von Heute
# Fetched 40 tracks from album 276/1684: New Pop Music
# Fetched 57 tracks from album 277/1684: Hit Music Hit Repeat
# Fetched 40 tracks from album 278/1684: Pop Internacional 2025
# Fetched 40 tracks from album 279/1684: New Pop Arrivals
# Fetched 30 tracks from album 280/1684: Pop Throwback
# Fetched 35 tracks from album 281/1684: sinónimo de tristeza
# Fetched 100 tracks from album 282/1684: 100 Greatest Songs for You Vol. 1
# Fetched 29 tracks from album 283/1684: Mellow Alt. Pop
# Fetched 24 tracks from album 284/1684: September
# Fetched 40 tracks from album 285/1684: Girls Brunch
# Fetched 60 tracks from album 286/1684: top hits 2000 - 2025
# Fetched 20 tracks from album 287/1684: hot tracks right now
# Fetched 55 tracks from album 288/1684: the coldest and darkest season
# Fetched 50 tracks from album 289/1684: Pop Tastic
# Fetched 19 tracks from album 290/1684: Help! A Day In The Life
# Fetched 100 tracks from album 291/1684: US Top 100 - The 10s
# Fetched 35 tracks from album 292/1684: Only Rock
# Fetched 50 tracks from album 293/1684: Años 2010
# Fetched 39 tracks from album 294/1684: Top Songs Radio
# Fetched 50 tracks from album 295/1684: Hits der Zweitausendzehner Jahre
# Fetched 50 tracks from album 296/1684: Push Rewind
# Fetched 57 tracks from album 297/1684: Awesome Top Chart Hits
# Fetched 26 tracks from album 298/1684: Get Moving
# Fetched 130 tracks from album 299/1684: Christmas Songs and Holiday Music
# Fetched 29 tracks from album 300/1684: pov: may nagpahiram ng payong
# Fetched 36 tracks from album 301/1684: Morning Hits
# Fetched 29 tracks from album 302/1684: On Melancholy Hill - Pop to Remember
# Fetched 73 tracks from album 303/1684: I Love You Amorcito
# Fetched 23 tracks from album 304/1684: no, I'm not okay
# Fetched 100 tracks from album 305/1684: 10s - Vibes of the Decade
# Fetched 20 tracks from album 306/1684: Happy Dance 2025
# Fetched 26 tracks from album 307/1684: Sound of Madness - Modern Rock Hits
# Fetched 35 tracks from album 308/1684: Clean Pop Aux Hits
# Fetched 50 tracks from album 309/1684: Fresh & New
# Fetched 40 tracks from album 310/1684: Zomer Vibes
# Fetched 30 tracks from album 311/1684: Baladas Épicas
# Fetched 48 tracks from album 312/1684: Ready To Play Vol 2
# Fetched 35 tracks from album 313/1684: Snake Year Vibes
# Fetched 100 tracks from album 314/1684: 100 Love Songs
# Fetched 57 tracks from album 315/1684: HIT SONGS ONLY
# Fetched 42 tracks from album 316/1684: Wedding Planner
# Fetched 34 tracks from album 317/1684: Sunday
# Fetched 34 tracks from album 318/1684: Soft Pop
# Fetched 65 tracks from album 319/1684: Pop Edition - New
# Fetched 55 tracks from album 320/1684: Hit Mode Activated
# Fetched 68 tracks from album 321/1684: Happy New Year 2023
# Fetched 100 tracks from album 322/1684: 10s HITS - 100 Greatest Songs of the 2010s
# Fetched 36 tracks from album 323/1684: Vem Outono 2025
# Fetched 80 tracks from album 324/1684: 10's Pop
# Fetched 45 tracks from album 325/1684: Soft Pop
# Fetched 50 tracks from album 326/1684: 50 BEST POP SONGS 2024
# Fetched 55 tracks from album 327/1684: All Stars 2025
# Fetched 100 tracks from album 328/1684: 100 from the 10s
# Fetched 29 tracks from album 329/1684: Canzoni del momento 2024
# Fetched 50 tracks from album 330/1684: Wedding Songs
# Fetched 45 tracks from album 331/1684: TikTok Songs You Can't Get Out of Your Head
# Fetched 47 tracks from album 332/1684: valentine's day 2024
# Fetched 55 tracks from album 333/1684: Happy Music
# Fetched 35 tracks from album 334/1684: Plener
# Fetched 12 tracks from album 335/1684: Heard On Heardle
# Fetched 31 tracks from album 336/1684: Peda de Halloween y Día de Muertos
# Fetched 36 tracks from album 337/1684: 2014 core
# Fetched 24 tracks from album 338/1684: TikTok Viral Hits 2024 2025
# Fetched 14 tracks from album 339/1684: lonely walks
# Fetched 24 tracks from album 340/1684: concert songs to listen (2000s)
# Fetched 20 tracks from album 341/1684: Friends
# Fetched 34 tracks from album 342/1684: Game Day Hype - Ultimate Sports Anthems
# Fetched 25 tracks from album 343/1684: New Pop Hits: 2025
# Fetched 39 tracks from album 344/1684: Hit italiane: le canzoni più ascoltate in Italia
# Fetched 100 tracks from album 345/1684: Hottest Hits 100 Greatest Songs of All Time
# Fetched 80 tracks from album 346/1684: Pop Classics - 10s
# Fetched 84 tracks from album 347/1684: greatest love songs ever
# Fetched 15 tracks from album 348/1684: you've had a hard day
# Fetched 60 tracks from album 349/1684: Playlist 20s
# Fetched 40 tracks from album 350/1684: Just the Way You Are - Hit Rewind
# Fetched 44 tracks from album 351/1684: Músicas Para Treinar Perna
# Fetched 23 tracks from album 352/1684: Relax al parco
# Fetched 28 tracks from album 353/1684: Soft Pop - Sunset
# Fetched 50 tracks from album 354/1684: Play Hard - 10s Anthems
# Fetched 23 tracks from album 355/1684: Campechanos
# Fetched 35 tracks from album 356/1684: Latino Hits 2025
# Fetched 10 tracks from album 357/1684: Until Now
# Fetched 39 tracks from album 358/1684: Fresh Bangers
# Fetched 35 tracks from album 359/1684: Viral Top Hits
# Fetched 48 tracks from album 360/1684: Two Birds - Songs I Heard On TikTok
# Fetched 63 tracks from album 361/1684: 70s, 80s, 90s & 2000s
# Fetched 55 tracks from album 362/1684: New Hits - Top Songs
# Fetched 35 tracks from album 363/1684: Sommarhits 2025
# Fetched 50 tracks from album 364/1684: 2010's-2020's Retrogamer
# Fetched 40 tracks from album 365/1684: Pop Music Central
# Fetched 50 tracks from album 366/1684: New Hits Rising
# Fetched 60 tracks from album 367/1684: Love Songs 2025
# Fetched 30 tracks from album 368/1684: Chill Morning - Breakfast Music 2025
# Fetched 62 tracks from album 369/1684: Canciones para aprender inglés
# Fetched 30 tracks from album 370/1684: Definitive Dance Anthems
# Fetched 50 tracks from album 371/1684: Hits 2025 - Today's Top Songs
# Fetched 26 tracks from album 372/1684: Relaxing Pop Music
# Fetched 27 tracks from album 373/1684: Musica per sognare
# Fetched 33 tracks from album 374/1684: Gute Laune Songs 2024
# Fetched 50 tracks from album 375/1684: hits galore
# Fetched 20 tracks from album 376/1684: THE BEST EVER: Time to Relax
# Fetched 58 tracks from album 377/1684: Morning Music
# Fetched 30 tracks from album 378/1684: Música Per Lavorare
# Fetched 50 tracks from album 379/1684: Want to Want Me - 10s Pop
# Fetched 100 tracks from album 380/1684: 100 Bästa Kärlekslåtarna
# Fetched 50 tracks from album 381/1684: Beautiful Songs
# Fetched 45 tracks from album 382/1684: hits on the rise
# Fetched 53 tracks from album 383/1684: Best Pub Songs Ever
# Fetched 35 tracks from album 384/1684: Tik Tok mania
# Fetched 33 tracks from album 385/1684: Good Vibes Good Energy
# Fetched 27 tracks from album 386/1684: Peaceful Pop
# Fetched 32 tracks from album 387/1684: New Year’s Eve Songs - NYE Party 2022
# Fetched 50 tracks from album 388/1684: club bangerz 20's edition
# Fetched 50 tracks from album 389/1684: Dance Mode: On
# Fetched 46 tracks from album 390/1684: very demure, very mindful
# Fetched 100 tracks from album 391/1684: 100 Greatest 10s
# Fetched 40 tracks from album 392/1684: It's You - 10s Acoustic
# Fetched 44 tracks from album 393/1684: Easy on Sunday
# Fetched 30 tracks from album 394/1684: Viral USA - Trending Now
# Fetched 94 tracks from album 395/1684: Top Hits: 2000 - 2020
# Fetched 25 tracks from album 396/1684: Cooking & Dancing
# Fetched 42 tracks from album 397/1684: Rock Revolution
# Fetched 27 tracks from album 398/1684: Songs to Dance... Alone
# Fetched 40 tracks from album 399/1684: Internet Pop Hits
# Fetched 18 tracks from album 400/1684: morning hawker walks
# Fetched 55 tracks from album 401/1684: Hits & New Drops
# Fetched 47 tracks from album 402/1684: Mix de la década dos mil diez
# Fetched 22 tracks from album 403/1684: Night Vibez
# Fetched 26 tracks from album 404/1684: Musica Soft per Smart Working
# Fetched 75 tracks from album 405/1684: 90er & 2000er Party
# Fetched 32 tracks from album 406/1684: Musica per stare a casa
# Fetched 30 tracks from album 407/1684: A Perfect Timing
# Fetched 75 tracks from album 408/1684: Canciones para dedicar - Románticas y corazón roto
# Fetched 35 tracks from album 409/1684: Top Hits Australia
# Fetched 27 tracks from album 410/1684: rainy day in bed
# Fetched 42 tracks from album 411/1684: Sad Songs - melancholic music
# Fetched 55 tracks from album 412/1684: Global Hot Hits
# Fetched 60 tracks from album 413/1684: Lovers of Music and Love
# Fetched 50 tracks from album 414/1684: TikTok Virale 2023
# Fetched 75 tracks from album 415/1684: best of 10s
# Fetched 55 tracks from album 416/1684: Music - Worldwide Hits 2024
# Fetched 50 tracks from album 417/1684: Throwback Party
# Fetched 50 tracks from album 418/1684: New Tunes & Hits
# Fetched 33 tracks from album 419/1684: Ritmo Estivo
# Fetched 28 tracks from album 420/1684: Hits Summer
# Fetched 75 tracks from album 421/1684: TikTok Viral Hits
# Fetched 30 tracks from album 422/1684: sad tiktok songs 2023
# Fetched 65 tracks from album 423/1684: 2024 Summed Up
# Fetched 40 tracks from album 424/1684: Fresh Out
# Fetched 44 tracks from album 425/1684: POP NOSTALGIA 2010s
# Fetched 50 tracks from album 426/1684: Play - Hits
# Fetched 28 tracks from album 427/1684: All Time Acoustic
# Fetched 50 tracks from album 428/1684: Acoustic Summer
# Fetched 50 tracks from album 429/1684: This Is Hits
# Fetched 26 tracks from album 430/1684: Spring Vibes
# Fetched 46 tracks from album 431/1684: sad summer songs
# Fetched 33 tracks from album 432/1684: Internet Finds - Going Viral
# Fetched 29 tracks from album 433/1684: 100% Floorfillers
# Fetched 66 tracks from album 434/1684: Top Dance Hits
# Fetched 100 tracks from album 435/1684: 100 Greatest 20s
# Fetched 39 tracks from album 436/1684: finally moving on
# Fetched 12 tracks from album 437/1684: Sad Boy Hours: Pop Edition
# Fetched 32 tracks from album 438/1684: Tormentoni estivi
# Fetched 30 tracks from album 439/1684: Dreamy Ballads
# Fetched 55 tracks from album 440/1684: Hits International
# Fetched 60 tracks from album 441/1684: Ritmadinha De Verão
# Fetched 47 tracks from album 442/1684: escucho de todo
# Fetched 35 tracks from album 443/1684: Chilled Acoustic
# Fetched 38 tracks from album 444/1684: Relaxing Pop: Now
# Fetched 48 tracks from album 445/1684: Para escuchar en VACACIONES DE INVIERNO 2024
# Fetched 21 tracks from album 446/1684: Surtido Alternativo
# Fetched 50 tracks from album 447/1684: brilliant bangers
# Fetched 100 tracks from album 448/1684: Shape of You - 10's Best
# Fetched 50 tracks from album 449/1684: Biggest Hits Right Now
# Fetched 55 tracks from album 450/1684: 90's Rock Anthems
# Fetched 40 tracks from album 451/1684: Hits Estate 2022
# Fetched 50 tracks from album 452/1684: Wedding Mixtape 2025
# Fetched 100 tracks from album 453/1684: 100 from the 00's - Rock
# Fetched 25 tracks from album 454/1684: Giornata felice
# Spotify call error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Fetched 65 tracks from album 455/1684: Koffietijd
# Fetched 26 tracks from album 456/1684: Inverno Vibes
# Fetched 22 tracks from album 457/1684: Viaggio in moto
# Fetched 75 tracks from album 458/1684: 10s Heroes
# Fetched 45 tracks from album 459/1684: Dance Nation
# Fetched 40 tracks from album 460/1684: Summer Nights
# Fetched 45 tracks from album 461/1684: Summertime
# Fetched 45 tracks from album 462/1684: 2000s Mixtape: Greatest Hits
# Fetched 30 tracks from album 463/1684: BS Achiever Major in Academic Validation
# Fetched 38 tracks from album 464/1684: HITS AND MORE HITS 2024
# Fetched 25 tracks from album 465/1684: Hard Times - Modern Rock Anthems
# Fetched 30 tracks from album 466/1684: Sad Bops
# Fetched 35 tracks from album 467/1684: GO WITH THE FLOW - Pop
# Fetched 100 tracks from album 468/1684: 100 beste festlåter
# Fetched 100 tracks from album 469/1684: Hits Cultes
# Fetched 40 tracks from album 470/1684: CHILL HITS
# Fetched 41 tracks from album 471/1684: Chill Dinner Music
# Fetched 25 tracks from album 472/1684: Rojak Rhythms
# Fetched 52 tracks from album 473/1684: Giro di Pasquetta
# Fetched 32 tracks from album 474/1684: Smile: Pop Hits
# Fetched 45 tracks from album 475/1684: We Don't Talk Anymore - Soft Pop
# Fetched 31 tracks from album 476/1684: Home Office - Músicas para Trabalhar 2024
# Fetched 30 tracks from album 477/1684: Weihnachten Rock
# Fetched 30 tracks from album 478/1684: Chilled Morning Mix | Summer Morning Vibes | Chill Vibes 2025
# Fetched 100 tracks from album 479/1684: 100 Greatest Pop Tracks
# Fetched 38 tracks from album 480/1684: Duvet Day Songs
# Fetched 37 tracks from album 481/1684: greatest driving songs: pop
# Fetched 45 tracks from album 482/1684: Hits Online
# Fetched 45 tracks from album 483/1684: Mi tesoro - Trending Tracks
# Fetched 41 tracks from album 484/1684: Jukebox: Hitovky z koncertů Ploužáky
# Fetched 22 tracks from album 485/1684: na Paz
# Fetched 40 tracks from album 486/1684: Soft Pop Hits 2025
# Fetched 55 tracks from album 487/1684: This is New Hits
# Fetched 51 tracks from album 488/1684: Músicas para Dias de Chuva
# Fetched 50 tracks from album 489/1684: Front Page Pop
# Fetched 90 tracks from album 490/1684: Cool Driving Songs
# Fetched 59 tracks from album 491/1684: Pop Now Vibes
# Fetched 60 tracks from album 492/1684: Chill Restaurant Music 2023
# Fetched 50 tracks from album 493/1684: Pop Top 2025
# Fetched 35 tracks from album 494/1684: Las Mejores Canciones de Amor
# Fetched 20 tracks from album 495/1684: Halloween Brasil 2024
# Fetched 30 tracks from album 496/1684: Big Rock Ballads
# Fetched 35 tracks from album 497/1684: Para dedicar en Inglés
# Fetched 38 tracks from album 498/1684: San Valentino 2024
# Fetched 50 tracks from album 499/1684: Fall 2024
# Fetched 35 tracks from album 500/1684: Top Éxitos España 2010-2020
# Fetched 30 tracks from album 501/1684: Take the Edge Off
# Fetched 36 tracks from album 502/1684: Titoli di coda
# Fetched 12 tracks from album 503/1684: The Hunger Games: Catching Fire (Original Motion Picture Soundtrack)
# Fetched 25 tracks from album 504/1684: Calm Pop Hits
# Fetched 81 tracks from album 505/1684: Happy New Year
# Fetched 30 tracks from album 506/1684: brb nangis dulu
# Fetched 100 tracks from album 507/1684: 100 best of the 10s
# Fetched 50 tracks from album 508/1684: Summer Hits 2000-2021
# Fetched 30 tracks from album 509/1684: cozy pop 2025
# Fetched 35 tracks from album 510/1684: Coffee Moment
# Fetched 40 tracks from album 511/1684: Slow Rock
# Fetched 63 tracks from album 512/1684: getting hitched
# Fetched 34 tracks from album 513/1684: Lugna Låtar
# Fetched 40 tracks from album 514/1684: Christmas in July The Hits
# Fetched 40 tracks from album 515/1684: Party Songs
# Fetched 35 tracks from album 516/1684: Summer Hits 2025
# Fetched 80 tracks from album 517/1684: 20s Hits - Best 20s Music
# Fetched 73 tracks from album 518/1684: Músicas para caixinha de som 2024
# Fetched 25 tracks from album 519/1684: Soft Piano Pop
# Fetched 32 tracks from album 520/1684: Storie d'amore
# Fetched 65 tracks from album 521/1684: Acoustic Rock
# Fetched 100 tracks from album 522/1684: #hits the 2010s
# Fetched 65 tracks from album 523/1684: Happy Friday Music | Uplifting Songs I Upbeat Music
# Fetched 100 tracks from album 524/1684: songs to sing in the car 100 hits
# Fetched 50 tracks from album 525/1684: Riptide - Acoustic Hits
# Fetched 50 tracks from album 526/1684: cozy fall morning acoustic
# Fetched 24 tracks from album 527/1684: Vatertag Sommerhits
# Fetched 34 tracks from album 528/1684: The Fire of Love
# Fetched 60 tracks from album 529/1684: pop menu hits mega pop top songs hot stuff
# Fetched 50 tracks from album 530/1684: Pop Filter
# Fetched 57 tracks from album 531/1684: Pop lento tranquilo
# Fetched 35 tracks from album 532/1684: Best Hot Tracks November 2024
# Fetched 100 tracks from album 533/1684: Best of 2000/2010er - 100 Hits
# Fetched 71 tracks from album 534/1684: Réveillon 2025
# Fetched 59 tracks from album 535/1684: TEMAZOS 2024
# Fetched 50 tracks from album 536/1684: Beyond the Charts 00's
# Fetched 37 tracks from album 537/1684: This Is Indie
# Fetched 50 tracks from album 538/1684: pop en ingles
# Fetched 54 tracks from album 539/1684: Twenty Tens
# Fetched 86 tracks from album 540/1684: Fiesta de verano
# Fetched 100 tracks from album 541/1684: 100 Chill Hits
# Fetched 44 tracks from album 542/1684: Uplifting Music
# Fetched 35 tracks from album 543/1684: rainy day in new york
# Fetched 30 tracks from album 544/1684: Zomerhits 2025
# Fetched 45 tracks from album 545/1684: Sounds of 2022
# Fetched 24 tracks from album 546/1684: Top Hits 2025
# Fetched 30 tracks from album 547/1684: Downtown Vibes
# Fetched 50 tracks from album 548/1684: Heard It On TikTok
# Fetched 38 tracks from album 549/1684: Musica Di Novembre 2024
# Fetched 40 tracks from album 550/1684: Big Bold Hits
# Fetched 40 tracks from album 551/1684: Clima de Inverno
# Fetched 25 tracks from album 552/1684: EDM Remixes of Popular Songs
# Fetched 35 tracks from album 553/1684: Spring Break 2025
# Fetched 30 tracks from album 554/1684: Yoga & Ballads
# Fetched 45 tracks from album 555/1684: new fresh pop hits
# Fetched 50 tracks from album 556/1684: Las 50 Mejores Canciones para Conducir
# Fetched 75 tracks from album 557/1684: Pop
# Fetched 50 tracks from album 558/1684: Clean School Songs
# Fetched 50 tracks from album 559/1684: Pop Chartbusters
# Fetched 50 tracks from album 560/1684: Gen Z Pop Music
# Fetched 101 tracks from album 561/1684: Retro Party Night - Retro Hits
# Fetched 105 tracks from album 562/1684: +100 Romantic and Cute Songs
# Fetched 43 tracks from album 563/1684: 2000er - Hitmix
# Fetched 27 tracks from album 564/1684: Modern Acoustic
# Fetched 44 tracks from album 565/1684: 2022
# Fetched 85 tracks from album 566/1684: 10s Hits - Best 10s Music
# Fetched 70 tracks from album 567/1684: Hottest 00s
# Fetched 31 tracks from album 568/1684: All Time Pop Ballads
# Fetched 30 tracks from album 569/1684: POV: Hai voglia di ballare
# Fetched 50 tracks from album 570/1684: Viral Internet Hits
# Fetched 30 tracks from album 571/1684: Successi in loop
# Fetched 44 tracks from album 572/1684: Treasure - Feel Good Anthems
# Fetched 34 tracks from album 573/1684: step into autumn
# Fetched 24 tracks from album 574/1684: Girl Club Bangers
# Fetched 45 tracks from album 575/1684: Pop News
# Fetched 65 tracks from album 576/1684: Goldeneye - Soundtrack Classics
# Fetched 40 tracks from album 577/1684: Summer Flashback 2024
# Fetched 60 tracks from album 578/1684: Pop Music 00's
# Fetched 30 tracks from album 579/1684: Hello Autumn 2024
# Fetched 30 tracks from album 580/1684: One Call Away - Best Friends Forever
# Fetched 40 tracks from album 581/1684: I'll Be Good - Soft 10's
# Fetched 50 tracks from album 582/1684: Pop Drive
# Fetched 36 tracks from album 583/1684: Relaxing Music - Chill Pop Vibes
# Fetched 50 tracks from album 584/1684: Lo Más Escuchado Verano 2024
# Fetched 48 tracks from album 585/1684: 10's Radio Gold
# Fetched 50 tracks from album 586/1684: Singled Out
# Fetched 35 tracks from album 587/1684: Somewhere in Brooklyn Easy Tens
# Fetched 29 tracks from album 588/1684: lugna sköna låtar
# Fetched 45 tracks from album 589/1684: Hits Sverige 2025
# Fetched 32 tracks from album 590/1684: Dinner
# Fetched 40 tracks from album 591/1684: Timeless and Romantic
# Fetched 50 tracks from album 592/1684: Coffeehouse Christmas
# Fetched 85 tracks from album 593/1684: Twenty Tens Hits
# Fetched 100 tracks from album 594/1684: TikTok Sounds
# Fetched 35 tracks from album 595/1684: Hurricane Relief: Come Together Now
# Fetched 50 tracks from album 596/1684: Best Hot Tracks July 2024
# Fetched 55 tracks from album 597/1684: Popcast
# Fetched 78 tracks from album 598/1684: Cupid's Playlist
# Fetched 32 tracks from album 599/1684: With Friends: Hits
# Fetched 50 tracks from album 600/1684: Dinner with Friends
# Fetched 30 tracks from album 601/1684: House Party
# Fetched 35 tracks from album 602/1684: Éxitos 2025
# Fetched 23 tracks from album 603/1684: Música para SAGITARIO 2024
# Fetched 30 tracks from album 604/1684: Hits on the Internet
# Fetched 30 tracks from album 605/1684: Amazing Day - Feelgood Pop
# Fetched 100 tracks from album 606/1684: Éxitos Clásicos en Inglés 100 Hits
# Fetched 30 tracks from album 607/1684: Lazy Chill Afternoon
# Fetched 30 tracks from album 608/1684: isa akong strong independent pop girlie
# Fetched 46 tracks from album 609/1684: Músicas Para Treinar
# Fetched 60 tracks from album 610/1684: Hits of the 90s,00s,10s
# Fetched 55 tracks from album 611/1684: Alternative Music - Hits
# Fetched 67 tracks from album 612/1684: good music - a perfect blend
# Fetched 45 tracks from album 613/1684: Fresh Pop Hits
# Fetched 30 tracks from album 614/1684: Onda Urbana
# Fetched 74 tracks from album 615/1684: Hitazos en inglés sin importar la década
# Fetched 44 tracks from album 616/1684: Cyber Hits
# Fetched 40 tracks from album 617/1684: Summer Chillout
# Fetched 46 tracks from album 618/1684: dosmileras
# Fetched 29 tracks from album 619/1684: Surtido Rico Vol. 7
# Fetched 30 tracks from album 620/1684: Victorious - Massive Alternative Tracks
# Fetched 55 tracks from album 621/1684: Pop New Bangers
# Fetched 28 tracks from album 622/1684: Ultimate Summer Hits
# Fetched 43 tracks from album 623/1684: TEMONES en Inglés
# Fetched 34 tracks from album 624/1684: Barbecue, Sun, Music
# Fetched 43 tracks from album 625/1684: True Love 2024
# Fetched 50 tracks from album 626/1684: Lugna Favoriter
# Fetched 25 tracks from album 627/1684: Emergency - 10's Dance
# Fetched 64 tracks from album 628/1684: Rock en Inglés 2010-2024
# Fetched 36 tracks from album 629/1684: Amanhecendo Na Estrada
# Fetched 39 tracks from album 630/1684: Call Me Papi - Viral Hits
# Fetched 26 tracks from album 631/1684: 00's Ballads
# Fetched 45 tracks from album 632/1684: Twenty Tens Ballads
# Fetched 20 tracks from album 633/1684: Sweet Pop 2025
# Fetched 43 tracks from album 634/1684: 2025 YAY!
# Fetched 26 tracks from album 635/1684: Clean Classroom Music
# Fetched 54 tracks from album 636/1684: Bailando con colores éxitos del orgullo
# Fetched 25 tracks from album 637/1684: cuando pienso en ti
# Fetched 36 tracks from album 638/1684: quiet winter morning
# Fetched 60 tracks from album 639/1684: Pure Throwback
# Fetched 19 tracks from album 640/1684: Pop & Trending
# Fetched 50 tracks from album 641/1684: Bangers of Pop
# Fetched 21 tracks from album 642/1684: New songs that just got released
# Fetched 50 tracks from album 643/1684: Top Pop
# Fetched 40 tracks from album 644/1684: Throwback 10's Pop Memories
# Fetched 55 tracks from album 645/1684: Hit Rewind
# Fetched 29 tracks from album 646/1684: Songs na mapanakit
# Fetched 80 tracks from album 647/1684: Melhores Hits Internacionais de Todos os Tempos
# Fetched 50 tracks from album 648/1684: twenty tens pop
# Fetched 46 tracks from album 649/1684: Una Lloradita Más
# Fetched 65 tracks from album 650/1684: Life Is Beautiful with Music
# Fetched 35 tracks from album 651/1684: Dark Academia Pop
# Fetched 34 tracks from album 652/1684: feels like fall air
# Fetched 50 tracks from album 653/1684: SAN VALENTIN 2024
# Fetched 12 tracks from album 654/1684: Grace
# Fetched 49 tracks from album 655/1684: Hits Focus Top Tracks 2025
# Fetched 53 tracks from album 656/1684: Le migliori canzoni per viaggiare
# Fetched 30 tracks from album 657/1684: Early 2000s Pop Rewind
# Fetched 29 tracks from album 658/1684: Alternativa Internacional
# Fetched 50 tracks from album 659/1684: Hit Music City
# Fetched 43 tracks from album 660/1684: Frühstück - Ruhige Musik
# Fetched 55 tracks from album 661/1684: Jaren 00 Hits
# Fetched 35 tracks from album 662/1684: Kesä 2025
# Fetched 50 tracks from album 663/1684: Summer Road Trip
# Fetched 46 tracks from album 664/1684: Poolside Pop
# Fetched 41 tracks from album 665/1684: SE JOGA!
# Fetched 60 tracks from album 666/1684: Invierno Musical
# Fetched 16 tracks from album 667/1684: Remember These?
# Fetched 30 tracks from album 668/1684: The Eldest Daughter
# Fetched 43 tracks from album 669/1684: Courage - You can do it
# Fetched 44 tracks from album 670/1684: 2024 - Happy New Year!
# Fetched 27 tracks from album 671/1684: Treino 2023: Músicas para malhar
# Fetched 25 tracks from album 672/1684: when life gives you durians
# Fetched 49 tracks from album 673/1684: Current Pop
# Fetched 40 tracks from album 674/1684: Summer Rock Vibes
# Fetched 26 tracks from album 675/1684: cold, but the tracks are hot
# Fetched 49 tracks from album 676/1684: Bridesmaids Getting Ready
# Fetched 39 tracks from album 677/1684: Soft
# Fetched 45 tracks from album 678/1684: pop pulse deluxe
# Fetched 50 tracks from album 679/1684: Chill Pop Hits
# Fetched 18 tracks from album 680/1684: Uplifting Feel Good Vibes
# Fetched 40 tracks from album 681/1684: 10s Best Ballads
# Fetched 50 tracks from album 682/1684: Top Tracks Hits Today
# Fetched 59 tracks from album 683/1684: Bops & Bangers
# Fetched 27 tracks from album 684/1684: Virales de Argentina
# Fetched 32 tracks from album 685/1684: 2000s Bangers
# Fetched 42 tracks from album 686/1684: Rock & Pop NYE Selection
# Fetched 55 tracks from album 687/1684: Pop
# Fetched 30 tracks from album 688/1684: All Day Acoustic
# Fetched 81 tracks from album 689/1684: New Years Eve
# Fetched 65 tracks from album 690/1684: Pedalata in bicicletta
# Fetched 65 tracks from album 691/1684: Timeless Love Songs
# Fetched 20 tracks from album 692/1684: Top 20 Hits 2024 - As Melhores do Momento
# Fetched 49 tracks from album 693/1684: Beggin' - What's Poppin?
# Fetched 34 tracks from album 694/1684: POV: Gustos Millenial
# Fetched 23 tracks from album 695/1684: Top Pop Rock Hits
# Fetched 25 tracks from album 696/1684: Soothing Acoustic
# Fetched 24 tracks from album 697/1684: As Mais Tocadas 2025
# Fetched 54 tracks from album 698/1684: Best of 2000
# Fetched 70 tracks from album 699/1684: Music for a Perfect Wedding
# Fetched 35 tracks from album 700/1684: Kaffeehausmusik
# Fetched 35 tracks from album 701/1684: Topplåtar 2025
# Fetched 33 tracks from album 702/1684: Sunshine Vibes
# Fetched 44 tracks from album 703/1684: looking after my mental health
# Fetched 27 tracks from album 704/1684: Estate Chill 2025
# Fetched 40 tracks from album 705/1684: memori anak 2000an
# Fetched 29 tracks from album 706/1684: pov ballads
# Fetched 100 tracks from album 707/1684: 100 Hits from the Movies
# Fetched 75 tracks from album 708/1684: Las 75 mejores baladas romanticas en ingles
# Fetched 40 tracks from album 709/1684: Chill Rock
# Fetched 55 tracks from album 710/1684: New Pop Drop
# Fetched 28 tracks from album 711/1684: Club Workout
# Fetched 13 tracks from album 712/1684: The Bakers Arms Dozen - A Fierce Panda Collection
# Fetched 100 tracks from album 713/1684: Top Tracks 20s
# Fetched 30 tracks from album 714/1684: Labor Day Weekend
# Fetched 30 tracks from album 715/1684: Relaxing Pet
# Fetched 30 tracks from album 716/1684: Canzoni in barca
# Fetched 33 tracks from album 717/1684: Las del Karaoke
# Fetched 25 tracks from album 718/1684: Soft Dance
# Fetched 26 tracks from album 719/1684: Día de las Madres en Argentina vol. 1
# Fetched 28 tracks from album 720/1684: Best Concert Songs (Soft Pop Edition)
# Fetched 44 tracks from album 721/1684: throwback magic classic hits
# Fetched 45 tracks from album 722/1684: Top Pop Artists 2024
# Fetched 30 tracks from album 723/1684: walang tulugan
# Fetched 27 tracks from album 724/1684: By the Way... Modern Rock
# Fetched 35 tracks from album 725/1684: tired of life
# Fetched 35 tracks from album 726/1684: Indie Island
# Fetched 100 tracks from album 727/1684: 2010s Bangers - 100 Hits
# Fetched 45 tracks from album 728/1684: Soft 00s
# Fetched 100 tracks from album 729/1684: Classic Road Trip Songs 100 Hits
# Fetched 20 tracks from album 730/1684: Melhores Pop Atual 2024
# Fetched 30 tracks from album 731/1684: Love Grows - Hot Acoustics
# Fetched 45 tracks from album 732/1684: pop hits refresh
# Fetched 35 tracks from album 733/1684: Sparks - Going Viral
# Fetched 30 tracks from album 734/1684: Lunes Tristón
# Fetched 30 tracks from album 735/1684: Melhores Músicas 2025
# Fetched 32 tracks from album 736/1684: Night Out Anthems
# Fetched 34 tracks from album 737/1684: Capital
# Fetched 24 tracks from album 738/1684: Ancora Una Volta
# Fetched 49 tracks from album 739/1684: Hits, Bops & Bangers
# Fetched 50 tracks from album 740/1684: Winter Hits 2025
# Fetched 50 tracks from album 741/1684: Hits For You
# Fetched 26 tracks from album 742/1684: Cool Music
# Fetched 40 tracks from album 743/1684: Good Feeling
# Fetched 18 tracks from album 744/1684: Música trendy - Julio 2025
# Fetched 40 tracks from album 745/1684: Cozy Autumn Vibes
# Fetched 25 tracks from album 746/1684: Rolas para estudiar
# Fetched 25 tracks from album 747/1684: Now And Forever: 25 Songs Of Love
# Fetched 60 tracks from album 748/1684: Friday Fun!
# Fetched 100 tracks from album 749/1684: Gen Alpha Gold
# Fetched 84 tracks from album 750/1684: Best Pop 2000-2025
# Fetched 29 tracks from album 751/1684: Top Sad Songs
# Fetched 60 tracks from album 752/1684: Cottage Vibes
# Fetched 40 tracks from album 753/1684: Sommar 2025
# Fetched 40 tracks from album 754/1684: Primavera 2022
# Fetched 42 tracks from album 755/1684: Fantastic Pop Now
# Fetched 40 tracks from album 756/1684: Happy Pop Aux
# Fetched 20 tracks from album 757/1684: Música para mi local
# Fetched 70 tracks from album 758/1684: Éxitos de los dos miles
# Fetched 29 tracks from album 759/1684: Hits nuevos y viejos
# Fetched 54 tracks from album 760/1684: Summer BBQ
# Fetched 54 tracks from album 761/1684: ROCK SONGS ~激熱お勧めのロック曲~
# Fetched 32 tracks from album 762/1684: Canzoni Autunnali
# Fetched 50 tracks from album 763/1684: Top canciones románticas en inglés
# Fetched 20 tracks from album 764/1684: do you ever think about dying
# Fetched 36 tracks from album 765/1684: Cena A Lume Di Candela
# Fetched 35 tracks from album 766/1684: TEMAZOS para el 2025
# Fetched 44 tracks from album 767/1684: Hits Septiembre 2023
# Fetched 30 tracks from album 768/1684: Alt Autumn
# Fetched 55 tracks from album 769/1684: Happy Flashback
# Fetched 20 tracks from album 770/1684: Trending Now - May 2025
# Fetched 50 tracks from album 771/1684: Pop Hits Roulette
# Fetched 44 tracks from album 772/1684: Mellow Hits
# Fetched 29 tracks from album 773/1684: Pure 10's Pop
# Fetched 41 tracks from album 774/1684: AUTUMN SONGS
# Fetched 70 tracks from album 775/1684: 00s Fever
# Fetched 29 tracks from album 776/1684: Sur La Route
# Fetched 34 tracks from album 777/1684: Beautiful Songs - Emotional Guys
# Fetched 26 tracks from album 778/1684: Summer Dance Hits 2025
# Fetched 40 tracks from album 779/1684: Winter's Love Songs
# Fetched 30 tracks from album 780/1684: i miss you na, 10pm na kasi
# Fetched 75 tracks from album 781/1684: Radio Oficina
# Fetched 28 tracks from album 782/1684: Caffè del buonumore
# Fetched 94 tracks from album 783/1684: Top Hits: 1980 - 2000
# Fetched 50 tracks from album 784/1684: Lentos y acústicos 2024
# Fetched 30 tracks from album 785/1684: Malapit na ang pasko, sana ako pa rin
# Fetched 43 tracks from album 786/1684: Radio Mix 2025
# Fetched 100 tracks from album 787/1684: 100 Greatest Hits of All Time
# Fetched 50 tracks from album 788/1684: Internacional Anos 2000
# Fetched 60 tracks from album 789/1684: Songs You Know By Heart Best from the 00s
# Fetched 40 tracks from album 790/1684: Dance Anthems
# Fetched 70 tracks from album 791/1684: INVIERNO DE MÚSICA LENTA
# Fetched 28 tracks from album 792/1684: Manejando en la lluvia
# Fetched 100 tracks from album 793/1684: 00s - Vibes of the Decade
# Fetched 60 tracks from album 794/1684: Playlist 10s
# Fetched 50 tracks from album 795/1684: Hits der Nullerjahre
# Fetched 40 tracks from album 796/1684: Hits 2024 Today's Hot Hits
# Fetched 30 tracks from album 797/1684: Flashback 10s
# Fetched 30 tracks from album 798/1684: Rock Acoustique
# Fetched 50 tracks from album 799/1684: new hot hits
# Fetched 30 tracks from album 800/1684: Sad Songs
# Fetched 28 tracks from album 801/1684: Cozy Morning
# Fetched 50 tracks from album 802/1684: Pop Flavour
# Fetched 100 tracks from album 803/1684: Movie Night
# ...
# Processed batch 1002/1390 of track ISRCs
# Processed batch 1003/1390 of track ISRCs
# Processed batch 1004/1390 of track ISRCs
# Processed batch 1005/1390 of track ISRCs
# Processed batch 1006/1390 of track ISRCs
# Processed batch 1007/1390 of track ISRCs
# Processed batch 1008/1390 of track ISRCs
# Processed batch 1009/1390 of track ISRCs
# Processed batch 1010/1390 of track ISRCs
# Processed batch 1011/1390 of track ISRCs
# Processed batch 1012/1390 of track ISRCs
# Processed batch 1013/1390 of track ISRCs
# Processed batch 1014/1390 of track ISRCs
# Processed batch 1015/1390 of track ISRCs
# Processed batch 1016/1390 of track ISRCs
# Processed batch 1017/1390 of track ISRCs
# Processed batch 1018/1390 of track ISRCs
# Processed batch 1019/1390 of track ISRCs
# Processed batch 1020/1390 of track ISRCs
# Processed batch 1021/1390 of track ISRCs
# Processed batch 1022/1390 of track ISRCs
# Processed batch 1023/1390 of track ISRCs
# Processed batch 1024/1390 of track ISRCs
# Processed batch 1025/1390 of track ISRCs
# Processed batch 1026/1390 of track ISRCs
# Processed batch 1027/1390 of track ISRCs
# Processed batch 1028/1390 of track ISRCs
# Processed batch 1029/1390 of track ISRCs
# Processed batch 1030/1390 of track ISRCs
# Processed batch 1031/1390 of track ISRCs
# Processed batch 1032/1390 of track ISRCs
# Processed batch 1033/1390 of track ISRCs
# Processed batch 1034/1390 of track ISRCs
# Processed batch 1035/1390 of track ISRCs
# Processed batch 1036/1390 of track ISRCs
# Processed batch 1037/1390 of track ISRCs
# Processed batch 1038/1390 of track ISRCs
# Processed batch 1039/1390 of track ISRCs
# Processed batch 1040/1390 of track ISRCs
# Processed batch 1041/1390 of track ISRCs
# Processed batch 1042/1390 of track ISRCs
# Processed batch 1043/1390 of track ISRCs
# Processed batch 1044/1390 of track ISRCs
# Processed batch 1045/1390 of track ISRCs
# Processed batch 1046/1390 of track ISRCs
# Processed batch 1047/1390 of track ISRCs
# Processed batch 1048/1390 of track ISRCs
# Processed batch 1049/1390 of track ISRCs
# Processed batch 1050/1390 of track ISRCs
# Processed batch 1051/1390 of track ISRCs
# Processed batch 1052/1390 of track ISRCs
# Processed batch 1053/1390 of track ISRCs
# Processed batch 1054/1390 of track ISRCs
# Processed batch 1055/1390 of track ISRCs
# Processed batch 1056/1390 of track ISRCs
# Processed batch 1057/1390 of track ISRCs
# Processed batch 1058/1390 of track ISRCs
# Processed batch 1059/1390 of track ISRCs
# Processed batch 1060/1390 of track ISRCs
# Processed batch 1061/1390 of track ISRCs
# Processed batch 1062/1390 of track ISRCs
# Processed batch 1063/1390 of track ISRCs
# Processed batch 1064/1390 of track ISRCs
# Processed batch 1065/1390 of track ISRCs
# Processed batch 1066/1390 of track ISRCs
# Processed batch 1067/1390 of track ISRCs
# Processed batch 1068/1390 of track ISRCs
# Processed batch 1069/1390 of track ISRCs
# Processed batch 1070/1390 of track ISRCs
# Processed batch 1071/1390 of track ISRCs
# Processed batch 1072/1390 of track ISRCs
# Processed batch 1073/1390 of track ISRCs
# Processed batch 1074/1390 of track ISRCs
# Processed batch 1075/1390 of track ISRCs
# Processed batch 1076/1390 of track ISRCs
# Processed batch 1077/1390 of track ISRCs
# Processed batch 1078/1390 of track ISRCs
# Processed batch 1079/1390 of track ISRCs
# Processed batch 1080/1390 of track ISRCs
# Processed batch 1081/1390 of track ISRCs
# Processed batch 1082/1390 of track ISRCs
# Processed batch 1083/1390 of track ISRCs
# Processed batch 1084/1390 of track ISRCs
# Processed batch 1085/1390 of track ISRCs
# Processed batch 1086/1390 of track ISRCs
# Processed batch 1087/1390 of track ISRCs
# Processed batch 1088/1390 of track ISRCs
# Processed batch 1089/1390 of track ISRCs
# Processed batch 1090/1390 of track ISRCs
# Processed batch 1091/1390 of track ISRCs
# Processed batch 1092/1390 of track ISRCs
# Processed batch 1093/1390 of track ISRCs
# Processed batch 1094/1390 of track ISRCs
# Processed batch 1095/1390 of track ISRCs
# Processed batch 1096/1390 of track ISRCs
# Processed batch 1097/1390 of track ISRCs
# Processed batch 1098/1390 of track ISRCs
# Processed batch 1099/1390 of track ISRCs
# Processed batch 1100/1390 of track ISRCs
# Processed batch 1101/1390 of track ISRCs
# Processed batch 1102/1390 of track ISRCs
# Processed batch 1103/1390 of track ISRCs
# Processed batch 1104/1390 of track ISRCs
# Processed batch 1105/1390 of track ISRCs
# Processed batch 1106/1390 of track ISRCs
# Processed batch 1107/1390 of track ISRCs
# Processed batch 1108/1390 of track ISRCs
# Processed batch 1109/1390 of track ISRCs
# Processed batch 1110/1390 of track ISRCs
# Processed batch 1111/1390 of track ISRCs
# Processed batch 1112/1390 of track ISRCs
# Processed batch 1113/1390 of track ISRCs
# Processed batch 1114/1390 of track ISRCs
# Processed batch 1115/1390 of track ISRCs
# Processed batch 1116/1390 of track ISRCs
# Processed batch 1117/1390 of track ISRCs
# Processed batch 1118/1390 of track ISRCs
# Processed batch 1119/1390 of track ISRCs
# Processed batch 1120/1390 of track ISRCs
# Processed batch 1121/1390 of track ISRCs
# Processed batch 1122/1390 of track ISRCs
# Processed batch 1123/1390 of track ISRCs
# Processed batch 1124/1390 of track ISRCs
# Processed batch 1125/1390 of track ISRCs
# Processed batch 1126/1390 of track ISRCs
# Processed batch 1127/1390 of track ISRCs
# Processed batch 1128/1390 of track ISRCs
# Processed batch 1129/1390 of track ISRCs
# Processed batch 1130/1390 of track ISRCs
# Processed batch 1131/1390 of track ISRCs
# Processed batch 1132/1390 of track ISRCs
# Processed batch 1133/1390 of track ISRCs
# Processed batch 1134/1390 of track ISRCs
# Processed batch 1135/1390 of track ISRCs
# Processed batch 1136/1390 of track ISRCs
# Processed batch 1137/1390 of track ISRCs
# Processed batch 1138/1390 of track ISRCs
# Processed batch 1139/1390 of track ISRCs
# Processed batch 1140/1390 of track ISRCs
# Processed batch 1141/1390 of track ISRCs
# Processed batch 1142/1390 of track ISRCs
# Processed batch 1143/1390 of track ISRCs
# Processed batch 1144/1390 of track ISRCs
# Processed batch 1145/1390 of track ISRCs
# Processed batch 1146/1390 of track ISRCs
# Processed batch 1147/1390 of track ISRCs
# Processed batch 1148/1390 of track ISRCs
# Processed batch 1149/1390 of track ISRCs
# Processed batch 1150/1390 of track ISRCs
# Processed batch 1151/1390 of track ISRCs
# Processed batch 1152/1390 of track ISRCs
# Processed batch 1153/1390 of track ISRCs
# Processed batch 1154/1390 of track ISRCs
# Processed batch 1155/1390 of track ISRCs
# Processed batch 1156/1390 of track ISRCs
# Processed batch 1157/1390 of track ISRCs
# Processed batch 1158/1390 of track ISRCs
# Processed batch 1159/1390 of track ISRCs
# Processed batch 1160/1390 of track ISRCs
# Processed batch 1161/1390 of track ISRCs
# Processed batch 1162/1390 of track ISRCs
# Processed batch 1163/1390 of track ISRCs
# Processed batch 1164/1390 of track ISRCs
# Processed batch 1165/1390 of track ISRCs
# Processed batch 1166/1390 of track ISRCs
# Processed batch 1167/1390 of track ISRCs
# Processed batch 1168/1390 of track ISRCs
# Processed batch 1169/1390 of track ISRCs
# Processed batch 1170/1390 of track ISRCs
# Processed batch 1171/1390 of track ISRCs
# Processed batch 1172/1390 of track ISRCs
# Processed batch 1173/1390 of track ISRCs
# Processed batch 1174/1390 of track ISRCs
# Processed batch 1175/1390 of track ISRCs
# Processed batch 1176/1390 of track ISRCs
# Processed batch 1177/1390 of track ISRCs
# Processed batch 1178/1390 of track ISRCs
# Processed batch 1179/1390 of track ISRCs
# Processed batch 1180/1390 of track ISRCs
# Processed batch 1181/1390 of track ISRCs
# Processed batch 1182/1390 of track ISRCs
# Processed batch 1183/1390 of track ISRCs
# Processed batch 1184/1390 of track ISRCs
# Processed batch 1185/1390 of track ISRCs
# Processed batch 1186/1390 of track ISRCs
# Processed batch 1187/1390 of track ISRCs
# Processed batch 1188/1390 of track ISRCs
# Processed batch 1189/1390 of track ISRCs
# Processed batch 1190/1390 of track ISRCs
# Processed batch 1191/1390 of track ISRCs
# Processed batch 1192/1390 of track ISRCs
# Processed batch 1193/1390 of track ISRCs
# Processed batch 1194/1390 of track ISRCs
# Processed batch 1195/1390 of track ISRCs
# Processed batch 1196/1390 of track ISRCs
# Processed batch 1197/1390 of track ISRCs
# Processed batch 1198/1390 of track ISRCs
# Processed batch 1199/1390 of track ISRCs
# Processed batch 1200/1390 of track ISRCs
# Processed batch 1201/1390 of track ISRCs
# Processed batch 1202/1390 of track ISRCs
# Processed batch 1203/1390 of track ISRCs
# Processed batch 1204/1390 of track ISRCs
# Processed batch 1205/1390 of track ISRCs
# Processed batch 1206/1390 of track ISRCs
# Processed batch 1207/1390 of track ISRCs
# Processed batch 1208/1390 of track ISRCs
# Processed batch 1209/1390 of track ISRCs
# Processed batch 1210/1390 of track ISRCs
# Processed batch 1211/1390 of track ISRCs
# Processed batch 1212/1390 of track ISRCs
# Processed batch 1213/1390 of track ISRCs
# Processed batch 1214/1390 of track ISRCs
# Processed batch 1215/1390 of track ISRCs
# Processed batch 1216/1390 of track ISRCs
# Processed batch 1217/1390 of track ISRCs
# Processed batch 1218/1390 of track ISRCs
# Processed batch 1219/1390 of track ISRCs
# Processed batch 1220/1390 of track ISRCs
# Processed batch 1221/1390 of track ISRCs
# Processed batch 1222/1390 of track ISRCs
# Processed batch 1223/1390 of track ISRCs
# Processed batch 1224/1390 of track ISRCs
# Processed batch 1225/1390 of track ISRCs
# Processed batch 1226/1390 of track ISRCs
# Processed batch 1227/1390 of track ISRCs
# Processed batch 1228/1390 of track ISRCs
# Processed batch 1229/1390 of track ISRCs
# Processed batch 1230/1390 of track ISRCs
# Processed batch 1231/1390 of track ISRCs
# Processed batch 1232/1390 of track ISRCs
# Processed batch 1233/1390 of track ISRCs
# Processed batch 1234/1390 of track ISRCs
# Processed batch 1235/1390 of track ISRCs
# Processed batch 1236/1390 of track ISRCs
# Processed batch 1237/1390 of track ISRCs
# Processed batch 1238/1390 of track ISRCs
# Processed batch 1239/1390 of track ISRCs
# Processed batch 1240/1390 of track ISRCs
# Processed batch 1241/1390 of track ISRCs
# Processed batch 1242/1390 of track ISRCs
# Processed batch 1243/1390 of track ISRCs
# Processed batch 1244/1390 of track ISRCs
# Processed batch 1245/1390 of track ISRCs
# Processed batch 1246/1390 of track ISRCs
# Processed batch 1247/1390 of track ISRCs
# Processed batch 1248/1390 of track ISRCs
# Processed batch 1249/1390 of track ISRCs
# Processed batch 1250/1390 of track ISRCs
# Processed batch 1251/1390 of track ISRCs
# Processed batch 1252/1390 of track ISRCs
# Processed batch 1253/1390 of track ISRCs
# Processed batch 1254/1390 of track ISRCs
# Processed batch 1255/1390 of track ISRCs
# Processed batch 1256/1390 of track ISRCs
# Processed batch 1257/1390 of track ISRCs
# Processed batch 1258/1390 of track ISRCs
# Processed batch 1259/1390 of track ISRCs
# Processed batch 1260/1390 of track ISRCs
# Processed batch 1261/1390 of track ISRCs
# Processed batch 1262/1390 of track ISRCs
# Processed batch 1263/1390 of track ISRCs
# Processed batch 1264/1390 of track ISRCs
# Processed batch 1265/1390 of track ISRCs
# Processed batch 1266/1390 of track ISRCs
# Processed batch 1267/1390 of track ISRCs
# Processed batch 1268/1390 of track ISRCs
# Processed batch 1269/1390 of track ISRCs
# Processed batch 1270/1390 of track ISRCs
# Processed batch 1271/1390 of track ISRCs
# Processed batch 1272/1390 of track ISRCs
# Processed batch 1273/1390 of track ISRCs
# Processed batch 1274/1390 of track ISRCs
# Processed batch 1275/1390 of track ISRCs
# Processed batch 1276/1390 of track ISRCs
# Processed batch 1277/1390 of track ISRCs
# Processed batch 1278/1390 of track ISRCs
# Processed batch 1279/1390 of track ISRCs
# Processed batch 1280/1390 of track ISRCs
# Processed batch 1281/1390 of track ISRCs
# Processed batch 1282/1390 of track ISRCs
# Processed batch 1283/1390 of track ISRCs
# Processed batch 1284/1390 of track ISRCs
# Processed batch 1285/1390 of track ISRCs
# Processed batch 1286/1390 of track ISRCs
# Processed batch 1287/1390 of track ISRCs
# Processed batch 1288/1390 of track ISRCs
# Processed batch 1289/1390 of track ISRCs
# Processed batch 1290/1390 of track ISRCs
# Processed batch 1291/1390 of track ISRCs
# Processed batch 1292/1390 of track ISRCs
# Processed batch 1293/1390 of track ISRCs
# Processed batch 1294/1390 of track ISRCs
# Processed batch 1295/1390 of track ISRCs
# Processed batch 1296/1390 of track ISRCs
# Processed batch 1297/1390 of track ISRCs
# Processed batch 1298/1390 of track ISRCs
# Processed batch 1299/1390 of track ISRCs
# Processed batch 1300/1390 of track ISRCs
# Processed batch 1301/1390 of track ISRCs
# Processed batch 1302/1390 of track ISRCs
# Processed batch 1303/1390 of track ISRCs
# Processed batch 1304/1390 of track ISRCs
# Processed batch 1305/1390 of track ISRCs
# Processed batch 1306/1390 of track ISRCs
# Processed batch 1307/1390 of track ISRCs
# Processed batch 1308/1390 of track ISRCs
# Processed batch 1309/1390 of track ISRCs
# Processed batch 1310/1390 of track ISRCs
# Processed batch 1311/1390 of track ISRCs
# Processed batch 1312/1390 of track ISRCs
# Processed batch 1313/1390 of track ISRCs
# Processed batch 1314/1390 of track ISRCs
# Processed batch 1315/1390 of track ISRCs
# Processed batch 1316/1390 of track ISRCs
# Processed batch 1317/1390 of track ISRCs
# Processed batch 1318/1390 of track ISRCs
# Processed batch 1319/1390 of track ISRCs
# Processed batch 1320/1390 of track ISRCs
# Processed batch 1321/1390 of track ISRCs
# Processed batch 1322/1390 of track ISRCs
# Processed batch 1323/1390 of track ISRCs
# Processed batch 1324/1390 of track ISRCs
# Processed batch 1325/1390 of track ISRCs
# Processed batch 1326/1390 of track ISRCs
# Processed batch 1327/1390 of track ISRCs
# Processed batch 1328/1390 of track ISRCs
# Processed batch 1329/1390 of track ISRCs
# Processed batch 1330/1390 of track ISRCs
# Processed batch 1331/1390 of track ISRCs
# Processed batch 1332/1390 of track ISRCs
# Processed batch 1333/1390 of track ISRCs
# Processed batch 1334/1390 of track ISRCs
# Processed batch 1335/1390 of track ISRCs
# Processed batch 1336/1390 of track ISRCs
# Processed batch 1337/1390 of track ISRCs
# Processed batch 1338/1390 of track ISRCs
# Processed batch 1339/1390 of track ISRCs
# Processed batch 1340/1390 of track ISRCs
# Processed batch 1341/1390 of track ISRCs
# Processed batch 1342/1390 of track ISRCs
# Processed batch 1343/1390 of track ISRCs
# Processed batch 1344/1390 of track ISRCs
# Processed batch 1345/1390 of track ISRCs
# Processed batch 1346/1390 of track ISRCs
# Processed batch 1347/1390 of track ISRCs
# Processed batch 1348/1390 of track ISRCs
# Processed batch 1349/1390 of track ISRCs
# Processed batch 1350/1390 of track ISRCs
# Processed batch 1351/1390 of track ISRCs
# Processed batch 1352/1390 of track ISRCs
# Processed batch 1353/1390 of track ISRCs
# Processed batch 1354/1390 of track ISRCs
# Processed batch 1355/1390 of track ISRCs
# Processed batch 1356/1390 of track ISRCs
# Processed batch 1357/1390 of track ISRCs
# Processed batch 1358/1390 of track ISRCs
# Processed batch 1359/1390 of track ISRCs
# Processed batch 1360/1390 of track ISRCs
# Processed batch 1361/1390 of track ISRCs
# Processed batch 1362/1390 of track ISRCs
# Processed batch 1363/1390 of track ISRCs
# Processed batch 1364/1390 of track ISRCs
# Processed batch 1365/1390 of track ISRCs
# Processed batch 1366/1390 of track ISRCs
# Processed batch 1367/1390 of track ISRCs
# Processed batch 1368/1390 of track ISRCs
# Processed batch 1369/1390 of track ISRCs
# Processed batch 1370/1390 of track ISRCs
# Processed batch 1371/1390 of track ISRCs
# Processed batch 1372/1390 of track ISRCs
# Processed batch 1373/1390 of track ISRCs
# Processed batch 1374/1390 of track ISRCs
# Processed batch 1375/1390 of track ISRCs
# Processed batch 1376/1390 of track ISRCs
# Processed batch 1377/1390 of track ISRCs
# Processed batch 1378/1390 of track ISRCs
# Processed batch 1379/1390 of track ISRCs
# Processed batch 1380/1390 of track ISRCs
# Processed batch 1381/1390 of track ISRCs
# Processed batch 1382/1390 of track ISRCs
# Processed batch 1383/1390 of track ISRCs
# Processed batch 1384/1390 of track ISRCs
# Processed batch 1385/1390 of track ISRCs
# Processed batch 1386/1390 of track ISRCs
# Processed batch 1387/1390 of track ISRCs
# Processed batch 1388/1390 of track ISRCs
# Processed batch 1389/1390 of track ISRCs
# Processed batch 1390/1390 of track ISRCs
# Tracks fetched: 69488

# %% [markdown]
# ## **Cross-Reference with Large TSV Dataset**
#
# - `unclaimedmusicalworkrightshares.tsv` is too large to load entirely (7GB).
# - Process the dataset in chunks using `chunksize`.
# - Standardize ISRC codes for accurate matching.
# - Filter matches with the artist catalog ISRCs.
# - Combine matched chunks into a final DataFrame.

# %%
import pandas as pd

def find_matches_in_large_tsv(tsv_path, artist_df, chunksize=100000):
    """
    Process large TSV in chunks, clean ISRC, and merge with artist catalog.
    Returns only the matching rows.
    """
    matches = []
    artist_isrcs = set(
        artist_df["isrc"].dropna().str.upper().str.strip().str.replace("-", "", regex=False).unique()
    )
    print(f"Searching {len(artist_isrcs)} ISRCs in dataset...")

    for chunk_num, chunk in enumerate(pd.read_csv(tsv_path, sep="\t", dtype=str, chunksize=chunksize, low_memory=False)):
        if "ISRC" not in chunk.columns:
            continue
        chunk["ISRC"] = chunk["ISRC"].astype(str).str.upper().str.strip().str.replace("-", "", regex=False)

        # Filter matches
        chunk_matches = chunk[chunk["ISRC"].isin(artist_isrcs)]
        if not chunk_matches.empty:
            print(f"✅ Found {len(chunk_matches)} matches in chunk {chunk_num}")
            matches.append(chunk_matches)

    if matches:
        return pd.concat(matches, ignore_index=True)
    else:
        return pd.DataFrame(columns=["ISRC"])

# %%
# load artist catalog created earlier
# (This should have columns: track_name, album_name, release_date, track_id, isrc)
artist_df = pd.read_csv("artist_catalog_with_isrcs.csv")

print("Tracks fetched from Spotify catalog:", len(artist_df))
artist_df.head()
# Out:
# Tracks fetched from Spotify catalog: 69488
#                  track_name  album_name release_date                track_id  \
# 0                MOON MUSiC  Moon Music   2024-10-04  41FNZsY7w7KaTQ2bjxdR6w
# 1  feelslikeimfallinginlove  Moon Music   2024-10-04  49S3znqBAQyPyMpEuKeyJ6
# 2                   WE PRAY  Moon Music   2024-10-04  7xrEnNo99wrmIs8ZK3RZMK
# 3                   JUPiTER  Moon Music   2024-10-04  3EbRbM7qyJq9qjRqDIwBTO
# 4             GOOD FEELiNGS  Moon Music   2024-10-04  65wzicJctsW9GwnTnLWxQO
#
#            isrc
# 0  GBAYE2400882
# 1  GBAYE2400891
# 2  GBAYE2400890
# 3  GBAYE2400883
# 4  GBAYE2400884

# %% [markdown]
# ## **Export Results to Excel**
#
# - Save all results in a single Excel file `final_artist_unclaimed.xlsx`.
# - Sheet 1: Artist Catalog with ISRCs.
# - Sheet 2: Matches (tracks found in unclaimed works).
# - Sheet 3: Notes & Observations about the workflow.
# - Memory-efficient and fully automated.

# %%
# Cross-reference artist catalog with large TSV
matches_df = find_matches_in_large_tsv("data/assessment.tsv", artist_df)

print("Tracks found in unclaimed dataset:", len(matches_df))

# Save to Excel
with pd.ExcelWriter("final_artist_unclaimed.xlsx", engine="openpyxl") as writer:
    artist_df.to_excel(writer, sheet_name="Artist Catalog", index=False)
    matches_df.to_excel(writer, sheet_name="Matches", index=False)

    notes_df = pd.DataFrame([
        ["Notes", "Used Spotify API to fetch full artist catalog."],
        ["Process", "Unclaimed dataset processed in chunks of 100k rows (7GB file)."],
        ["Matches Found", str(len(matches_df))],
    ], columns=["Key", "Value"])
    notes_df.to_excel(writer, sheet_name="Notes", index=False)

print("✅ Excel file created: final_artist_unclaimed.xlsx")
# Out:
# Searching 11510 ISRCs in dataset...
# ✅ Found 901 matches in chunk 0
# ✅ Found 888 matches in chunk 1
# ✅ Found 831 matches in chunk 2
# ✅ Found 752 matches in chunk 3
# ✅ Found 755 matches in chunk 4
# ✅ Found 862 matches in chunk 5
# ✅ Found 751 matches in chunk 6
# ✅ Found 854 matches in chunk 7
# ✅ Found 889 matches in chunk 8
# ✅ Found 788 matches in chunk 9
# ✅ Found 896 matches in chunk 10
# ✅ Found 792 matches in chunk 11
# ✅ Found 804 matches in chunk 12
# ✅ Found 827 matches in chunk 13
# ✅ Found 932 matches in chunk 14
# ✅ Found 916 matches in chunk 15
# ✅ Found 781 matches in chunk 16
# ✅ Found 898 matches in chunk 17
# ✅ Found 858 matches in chunk 18
# ✅ Found 928 matches in chunk 19
# ✅ Found 814 matches in chunk 20
# ✅ Found 885 matches in chunk 21
# ✅ Found 685 matches in chunk 22
# ✅ Found 876 matches in chunk 23
# ✅ Found 793 matches in chunk 24
# ✅ Found 840 matches in chunk 25
# ✅ Found 745 matches in chunk 26
# ✅ Found 797 matches in chunk 27
# ✅ Found 738 matches in chunk 28
# ✅ Found 796 matches in chunk 29
# ✅ Found 807 matches in chunk 30
# ✅ Found 766 matches in chunk 31
# ✅ Found 748 matches in chunk 32
# ✅ Found 864 matches in chunk 33
# ✅ Found 816 matches in chunk 34
# ✅ Found 793 matches in chunk 35
# ✅ Found 806 matches in chunk 36
# ✅ Found 799 matches in chunk 37
# ✅ Found 827 matches in chunk 38
# ✅ Found 741 matches in chunk 39
# ✅ Found 741 matches in chunk 40
# ✅ Found 791 matches in chunk 41
# ✅ Found 878 matches in chunk 42
# ✅ Found 806 matches in chunk 43
# ✅ Found 936 matches in chunk 44
# ✅ Found 903 matches in chunk 45
# ✅ Found 761 matches in chunk 46
# ✅ Found 893 matches in chunk 47
# ✅ Found 795 matches in chunk 48
# ✅ Found 759 matches in chunk 49
# ✅ Found 863 matches in chunk 50
# ✅ Found 1006 matches in chunk 51
# ✅ Found 746 matches in chunk 52
# ✅ Found 897 matches in chunk 53
# ✅ Found 806 matches in chunk 54
# ✅ Found 742 matches in chunk 55
# ✅ Found 847 matches in chunk 56
# ✅ Found 959 matches in chunk 57
# ✅ Found 845 matches in chunk 58
# ✅ Found 761 matches in chunk 59
# ✅ Found 948 matches in chunk 60
# ✅ Found 798 matches in chunk 61
# ✅ Found 794 matches in chunk 62
# ✅ Found 739 matches in chunk 63
# ✅ Found 823 matches in chunk 64
# ✅ Found 870 matches in chunk 65
# ✅ Found 793 matches in chunk 66
# ✅ Found 920 matches in chunk 67
# ✅ Found 780 matches in chunk 68
# ✅ Found 851 matches in chunk 69
# ✅ Found 915 matches in chunk 70
# ✅ Found 947 matches in chunk 71
# ✅ Found 765 matches in chunk 72
# ✅ Found 771 matches in chunk 73
# ✅ Found 935 matches in chunk 74
# ✅ Found 858 matches in chunk 75
# ✅ Found 767 matches in chunk 76
# ✅ Found 844 matches in chunk 77
# ✅ Found 900 matches in chunk 78
# ✅ Found 962 matches in chunk 79
# ✅ Found 782 matches in chunk 80
# ✅ Found 972 matches in chunk 81
# ✅ Found 935 matches in chunk 82
# ✅ Found 824 matches in chunk 83
# ✅ Found 978 matches in chunk 84
# ✅ Found 756 matches in chunk 85
# ✅ Found 663 matches in chunk 86
# ✅ Found 740 matches in chunk 87
# ✅ Found 715 matches in chunk 88
# ✅ Found 717 matches in chunk 89
# ✅ Found 749 matches in chunk 90
# ✅ Found 755 matches in chunk 91
# ✅ Found 783 matches in chunk 92
# ✅ Found 752 matches in chunk 93
# ✅ Found 625 matches in chunk 94
# ✅ Found 872 matches in chunk 95
# ✅ Found 699 matches in chunk 96
# ✅ Found 769 matches in chunk 97
# ✅ Found 703 matches in chunk 98
# ✅ Found 671 matches in chunk 99
# ✅ Found 759 matches in chunk 100
# ✅ Found 706 matches in chunk 101
# ✅ Found 736 matches in chunk 102
# ✅ Found 691 matches in chunk 103
# ✅ Found 706 matches in chunk 104
# ✅ Found 692 matches in chunk 105
# ✅ Found 657 matches in chunk 106
# ✅ Found 693 matches in chunk 107
# ✅ Found 721 matches in chunk 108
# ✅ Found 661 matches in chunk 109
# ✅ Found 610 matches in chunk 110
# ✅ Found 611 matches in chunk 111
# ✅ Found 731 matches in chunk 112
# ✅ Found 652 matches in chunk 113
# ✅ Found 674 matches in chunk 114
# ✅ Found 809 matches in chunk 115
# ✅ Found 617 matches in chunk 116
# ✅ Found 713 matches in chunk 117
# ✅ Found 596 matches in chunk 118
# ✅ Found 791 matches in chunk 119
# ✅ Found 735 matches in chunk 120
# ✅ Found 689 matches in chunk 121
# ✅ Found 513 matches in chunk 122
# ✅ Found 727 matches in chunk 123
# ✅ Found 641 matches in chunk 124
# ✅ Found 609 matches in chunk 125
# ✅ Found 615 matches in chunk 126
# ✅ Found 579 matches in chunk 127
# ✅ Found 589 matches in chunk 128
# ✅ Found 702 matches in chunk 129
# ✅ Found 652 matches in chunk 130
# ✅ Found 602 matches in chunk 131
# ✅ Found 605 matches in chunk 132
# ✅ Found 619 matches in chunk 133
# ✅ Found 497 matches in chunk 134
# ✅ Found 615 matches in chunk 135
# ✅ Found 581 matches in chunk 136
# ✅ Found 620 matches in chunk 137
# ✅ Found 629 matches in chunk 138
# ✅ Found 585 matches in chunk 139
# ✅ Found 588 matches in chunk 140
# ✅ Found 519 matches in chunk 141
# ✅ Found 629 matches in chunk 142
# ✅ Found 779 matches in chunk 143
# ✅ Found 650 matches in chunk 144
# ✅ Found 570 matches in chunk 145
# ✅ Found 727 matches in chunk 146
# ✅ Found 698 matches in chunk 147
# ✅ Found 606 matches in chunk 148
# ✅ Found 819 matches in chunk 149
# ✅ Found 565 matches in chunk 150
# ✅ Found 645 matches in chunk 151
# ✅ Found 661 matches in chunk 152
# ✅ Found 528 matches in chunk 153
# ✅ Found 526 matches in chunk 154
# ✅ Found 586 matches in chunk 155
# ✅ Found 670 matches in chunk 156
# ✅ Found 624 matches in chunk 157
# ✅ Found 660 matches in chunk 158
# ✅ Found 565 matches in chunk 159
# ✅ Found 641 matches in chunk 160
# ✅ Found 720 matches in chunk 161
# ✅ Found 824 matches in chunk 162
# ✅ Found 845 matches in chunk 163
# ✅ Found 735 matches in chunk 164
# ✅ Found 719 matches in chunk 165
# ✅ Found 769 matches in chunk 166
# ✅ Found 855 matches in chunk 167
# ✅ Found 727 matches in chunk 168
# ✅ Found 849 matches in chunk 169
# ✅ Found 882 matches in chunk 170
# ✅ Found 738 matches in chunk 171
# ✅ Found 654 matches in chunk 172
# ✅ Found 860 matches in chunk 173
# ✅ Found 713 matches in chunk 174
# ✅ Found 953 matches in chunk 175
# ✅ Found 989 matches in chunk 176
# ✅ Found 750 matches in chunk 177
# ✅ Found 718 matches in chunk 178
# ✅ Found 749 matches in chunk 179
# ✅ Found 785 matches in chunk 180
# ✅ Found 792 matches in chunk 181
# ✅ Found 519 matches in chunk 182
# ✅ Found 874 matches in chunk 183
# ✅ Found 915 matches in chunk 184
# ✅ Found 707 matches in chunk 185
# ✅ Found 675 matches in chunk 186
# ✅ Found 767 matches in chunk 187
# ✅ Found 680 matches in chunk 188
# ✅ Found 751 matches in chunk 189
# ✅ Found 717 matches in chunk 190
# ✅ Found 993 matches in chunk 191
# ✅ Found 668 matches in chunk 192
# ✅ Found 714 matches in chunk 193
# ✅ Found 738 matches in chunk 194
# ✅ Found 693 matches in chunk 195
# ✅ Found 709 matches in chunk 196
# ✅ Found 818 matches in chunk 197
# ✅ Found 734 matches in chunk 198
# ✅ Found 908 matches in chunk 199
# ✅ Found 820 matches in chunk 200
# ✅ Found 679 matches in chunk 201
# ✅ Found 609 matches in chunk 202
# ✅ Found 899 matches in chunk 203
# ✅ Found 908 matches in chunk 204
# ✅ Found 819 matches in chunk 205
# ✅ Found 1072 matches in chunk 206
# ✅ Found 839 matches in chunk 207
# ✅ Found 768 matches in chunk 208
# ✅ Found 1041 matches in chunk 209
# ✅ Found 655 matches in chunk 210
# ✅ Found 1009 matches in chunk 211
# ✅ Found 757 matches in chunk 212
# ✅ Found 676 matches in chunk 213
# ✅ Found 977 matches in chunk 214
# ✅ Found 628 matches in chunk 215
# ✅ Found 874 matches in chunk 216
# ✅ Found 862 matches in chunk 217
# ✅ Found 871 matches in chunk 218
# ✅ Found 960 matches in chunk 219
# ✅ Found 827 matches in chunk 220
# ✅ Found 984 matches in chunk 221
# ✅ Found 825 matches in chunk 222
# ✅ Found 786 matches in chunk 223
# ✅ Found 685 matches in chunk 224
# ✅ Found 730 matches in chunk 225
# ✅ Found 831 matches in chunk 226
# ✅ Found 938 matches in chunk 227
# ✅ Found 818 matches in chunk 228
# ✅ Found 722 matches in chunk 229
# ✅ Found 907 matches in chunk 230
# ✅ Found 738 matches in chunk 231
# ✅ Found 843 matches in chunk 232
# ✅ Found 1042 matches in chunk 233
# ✅ Found 899 matches in chunk 234
# ✅ Found 683 matches in chunk 235
# ✅ Found 729 matches in chunk 236
# ✅ Found 927 matches in chunk 237
# ✅ Found 765 matches in chunk 238
# ✅ Found 774 matches in chunk 239
# ✅ Found 1005 matches in chunk 240
# ✅ Found 804 matches in chunk 241
# ✅ Found 710 matches in chunk 242
# ✅ Found 783 matches in chunk 243
# ✅ Found 787 matches in chunk 244
# ✅ Found 828 matches in chunk 245
# ✅ Found 636 matches in chunk 246
# ✅ Found 683 matches in chunk 247
# ✅ Found 748 matches in chunk 248
# ✅ Found 902 matches in chunk 249
# ✅ Found 714 matches in chunk 250
# ✅ Found 1020 matches in chunk 251
# ✅ Found 707 matches in chunk 252
# ✅ Found 995 matches in chunk 253
# ✅ Found 811 matches in chunk 254
# ✅ Found 854 matches in chunk 255
# ✅ Found 664 matches in chunk 256
# ✅ Found 819 matches in chunk 257
# ✅ Found 787 matches in chunk 258
# ✅ Found 756 matches in chunk 259
# ✅ Found 807 matches in chunk 260
# ✅ Found 985 matches in chunk 261
# ✅ Found 842 matches in chunk 262
# ✅ Found 981 matches in chunk 263
# ✅ Found 784 matches in chunk 264
# ✅ Found 620 matches in chunk 265
# ✅ Found 844 matches in chunk 266
# ✅ Found 868 matches in chunk 267
# ✅ Found 692 matches in chunk 268
# ✅ Found 678 matches in chunk 269
# ✅ Found 785 matches in chunk 270
# ✅ Found 979 matches in chunk 271
# ✅ Found 759 matches in chunk 272
# ✅ Found 859 matches in chunk 273
# ✅ Found 918 matches in chunk 274
# ✅ Found 824 matches in chunk 275
# ✅ Found 698 matches in chunk 276
# ✅ Found 893 matches in chunk 277
# ✅ Found 884 matches in chunk 278
# ✅ Found 1040 matches in chunk 279
# ✅ Found 948 matches in chunk 280
# ✅ Found 764 matches in chunk 281
# ✅ Found 847 matches in chunk 282
# ✅ Found 796 matches in chunk 283
# ✅ Found 870 matches in chunk 284
# ✅ Found 747 matches in chunk 285
# ✅ Found 1076 matches in chunk 286
# ✅ Found 846 matches in chunk 287
# ✅ Found 902 matches in chunk 288
# ✅ Found 1019 matches in chunk 289
# ✅ Found 931 matches in chunk 290
# ✅ Found 686 matches in chunk 291
# ✅ Found 902 matches in chunk 292
# ✅ Found 817 matches in chunk 293
# ✅ Found 1110 matches in chunk 294
# ✅ Found 704 matches in chunk 295
# ✅ Found 783 matches in chunk 296
# ✅ Found 1104 matches in chunk 297
# ✅ Found 759 matches in chunk 298
# ✅ Found 818 matches in chunk 299
# ✅ Found 861 matches in chunk 300
# ✅ Found 700 matches in chunk 301
# ✅ Found 1057 matches in chunk 302
# ✅ Found 916 matches in chunk 303
# ✅ Found 1011 matches in chunk 304
# ✅ Found 1042 matches in chunk 305
# ✅ Found 830 matches in chunk 306
# ✅ Found 755 matches in chunk 307
# ✅ Found 901 matches in chunk 308
# ✅ Found 1160 matches in chunk 309
# ✅ Found 800 matches in chunk 310
# ✅ Found 787 matches in chunk 311
# ✅ Found 1020 matches in chunk 312
# ✅ Found 991 matches in chunk 313
# ✅ Found 862 matches in chunk 314
# ✅ Found 654 matches in chunk 315
# ✅ Found 1141 matches in chunk 316
# ✅ Found 824 matches in chunk 317
# ✅ Found 959 matches in chunk 318
# ✅ Found 769 matches in chunk 319
# ✅ Found 887 matches in chunk 320
# ✅ Found 802 matches in chunk 321
# ✅ Found 679 matches in chunk 322
# ✅ Found 769 matches in chunk 323
# ✅ Found 745 matches in chunk 324
# ✅ Found 791 matches in chunk 325
# ✅ Found 737 matches in chunk 326
# ✅ Found 739 matches in chunk 327
# ✅ Found 696 matches in chunk 328
# ✅ Found 827 matches in chunk 329
# ✅ Found 755 matches in chunk 330
# ✅ Found 775 matches in chunk 331
# ✅ Found 813 matches in chunk 332
# ✅ Found 704 matches in chunk 333
# ✅ Found 1086 matches in chunk 334
# ✅ Found 928 matches in chunk 335
# ✅ Found 890 matches in chunk 336
# ✅ Found 845 matches in chunk 337
# ✅ Found 828 matches in chunk 338
# ✅ Found 828 matches in chunk 339
# ✅ Found 828 matches in chunk 340
# ✅ Found 733 matches in chunk 341
# ✅ Found 775 matches in chunk 342
# ✅ Found 845 matches in chunk 343
# ✅ Found 806 matches in chunk 344
# ✅ Found 753 matches in chunk 345
# ✅ Found 792 matches in chunk 346
# ✅ Found 924 matches in chunk 347
# ✅ Found 941 matches in chunk 348
# ✅ Found 847 matches in chunk 349
# ✅ Found 841 matches in chunk 350
# ✅ Found 858 matches in chunk 351
# ✅ Found 852 matches in chunk 352
# ✅ Found 719 matches in chunk 353
# ✅ Found 790 matches in chunk 354
# ✅ Found 888 matches in chunk 355
# ✅ Found 1047 matches in chunk 356
# ✅ Found 723 matches in chunk 357
# ✅ Found 709 matches in chunk 358
# ✅ Found 1065 matches in chunk 359
# ✅ Found 1075 matches in chunk 360
# ✅ Found 889 matches in chunk 361
# ✅ Found 956 matches in chunk 362
# ✅ Found 977 matches in chunk 363
# ✅ Found 679 matches in chunk 364
# ✅ Found 964 matches in chunk 365
# ✅ Found 1006 matches in chunk 366
# ✅ Found 790 matches in chunk 367
# ✅ Found 851 matches in chunk 368
# ✅ Found 1039 matches in chunk 369
# ✅ Found 926 matches in chunk 370
# ✅ Found 717 matches in chunk 371
# ✅ Found 957 matches in chunk 372
# ✅ Found 827 matches in chunk 373
# ✅ Found 927 matches in chunk 374
# ✅ Found 695 matches in chunk 375
# ✅ Found 754 matches in chunk 376
# ✅ Found 726 matches in chunk 377
# ✅ Found 742 matches in chunk 378
# ✅ Found 791 matches in chunk 379
# ✅ Found 987 matches in chunk 380
# ✅ Found 1132 matches in chunk 381
# ✅ Found 863 matches in chunk 382
# ✅ Found 855 matches in chunk 383
# ✅ Found 718 matches in chunk 384
# ✅ Found 713 matches in chunk 385
# ✅ Found 920 matches in chunk 386
# ✅ Found 673 matches in chunk 387
# ✅ Found 871 matches in chunk 388
# ✅ Found 822 matches in chunk 389
# ✅ Found 802 matches in chunk 390
# ✅ Found 651 matches in chunk 391
# ✅ Found 730 matches in chunk 392
# ✅ Found 746 matches in chunk 393
# ✅ Found 953 matches in chunk 394
# ✅ Found 759 matches in chunk 395
# ✅ Found 719 matches in chunk 396
# ✅ Found 880 matches in chunk 397
# ✅ Found 857 matches in chunk 398
# ✅ Found 1018 matches in chunk 399
# ✅ Found 847 matches in chunk 400
# ✅ Found 688 matches in chunk 401
# ✅ Found 805 matches in chunk 402
# ✅ Found 825 matches in chunk 403
# ✅ Found 990 matches in chunk 404
# ✅ Found 787 matches in chunk 405
# ✅ Found 832 matches in chunk 406
# ✅ Found 821 matches in chunk 407
# ✅ Found 785 matches in chunk 408
# ✅ Found 784 matches in chunk 409
# ✅ Found 757 matches in chunk 410
# ✅ Found 797 matches in chunk 411
# ✅ Found 725 matches in chunk 412
# ✅ Found 774 matches in chunk 413
# ✅ Found 950 matches in chunk 414
# ✅ Found 763 matches in chunk 415
# ✅ Found 904 matches in chunk 416
# ✅ Found 839 matches in chunk 417
# ✅ Found 972 matches in chunk 418
# ✅ Found 997 matches in chunk 419
# ✅ Found 699 matches in chunk 420
# ✅ Found 1057 matches in chunk 421
# ✅ Found 1064 matches in chunk 422
# ✅ Found 867 matches in chunk 423
# ✅ Found 876 matches in chunk 424
# ✅ Found 780 matches in chunk 425
# ✅ Found 731 matches in chunk 426
# ✅ Found 713 matches in chunk 427
# ✅ Found 900 matches in chunk 428
# ✅ Found 978 matches in chunk 429
# ✅ Found 1013 matches in chunk 430
# ✅ Found 821 matches in chunk 431
# ✅ Found 862 matches in chunk 432
# ✅ Found 951 matches in chunk 433
# ✅ Found 782 matches in chunk 434
# ✅ Found 1045 matches in chunk 435
# ✅ Found 875 matches in chunk 436
# ✅ Found 821 matches in chunk 437
# ✅ Found 724 matches in chunk 438
# ✅ Found 698 matches in chunk 439
# ✅ Found 697 matches in chunk 440
# ✅ Found 1091 matches in chunk 441
# ✅ Found 702 matches in chunk 442
# ✅ Found 787 matches in chunk 443
# ✅ Found 1166 matches in chunk 444
# ✅ Found 707 matches in chunk 445
# ✅ Found 904 matches in chunk 446
# ✅ Found 854 matches in chunk 447
# ✅ Found 714 matches in chunk 448
# ✅ Found 845 matches in chunk 449
# ✅ Found 872 matches in chunk 450
# ✅ Found 932 matches in chunk 451
# ✅ Found 850 matches in chunk 452
# ✅ Found 919 matches in chunk 453
# ✅ Found 854 matches in chunk 454
# ✅ Found 685 matches in chunk 455
# ✅ Found 812 matches in chunk 456
# ✅ Found 934 matches in chunk 457
# ✅ Found 680 matches in chunk 458
# ✅ Found 716 matches in chunk 459
# ✅ Found 876 matches in chunk 460
# ✅ Found 926 matches in chunk 461
# ✅ Found 912 matches in chunk 462
# ✅ Found 724 matches in chunk 463
# ✅ Found 776 matches in chunk 464
# ✅ Found 779 matches in chunk 465
# ✅ Found 835 matches in chunk 466
# ✅ Found 877 matches in chunk 467
# ✅ Found 898 matches in chunk 468
# ✅ Found 776 matches in chunk 469
# ✅ Found 770 matches in chunk 470
# ✅ Found 1091 matches in chunk 471
# ✅ Found 854 matches in chunk 472
# ✅ Found 1025 matches in chunk 473
# ✅ Found 742 matches in chunk 474
# ✅ Found 703 matches in chunk 475
# ✅ Found 752 matches in chunk 476
# ✅ Found 636 matches in chunk 477
# ✅ Found 710 matches in chunk 478
# ✅ Found 881 matches in chunk 479
# ✅ Found 895 matches in chunk 480
# ✅ Found 706 matches in chunk 481
# ✅ Found 868 matches in chunk 482
# ✅ Found 825 matches in chunk 483
# ✅ Found 772 matches in chunk 484
# ✅ Found 862 matches in chunk 485
# ✅ Found 894 matches in chunk 486
# ✅ Found 865 matches in chunk 487
# ✅ Found 932 matches in chunk 488
# ✅ Found 897 matches in chunk 489
# ✅ Found 753 matches in chunk 490
# ✅ Found 1006 matches in chunk 491
# ✅ Found 919 matches in chunk 492
# ✅ Found 791 matches in chunk 493
# ✅ Found 779 matches in chunk 494
# ✅ Found 865 matches in chunk 495
# ✅ Found 798 matches in chunk 496
# ✅ Found 824 matches in chunk 497
# ✅ Found 791 matches in chunk 498
# ✅ Found 824 matches in chunk 499
# ✅ Found 675 matches in chunk 500
# ✅ Found 746 matches in chunk 501
# ✅ Found 712 matches in chunk 502
# ✅ Found 931 matches in chunk 503
# ✅ Found 739 matches in chunk 504
# ✅ Found 811 matches in chunk 505
# ✅ Found 680 matches in chunk 506
# ✅ Found 812 matches in chunk 507
# ✅ Found 921 matches in chunk 508
# ✅ Found 683 matches in chunk 509
# ✅ Found 733 matches in chunk 510
# ✅ Found 726 matches in chunk 511
# ✅ Found 924 matches in chunk 512
# ✅ Found 999 matches in chunk 513
# ✅ Found 874 matches in chunk 514
# ✅ Found 945 matches in chunk 515
# ✅ Found 834 matches in chunk 516
# ✅ Found 759 matches in chunk 517
# ✅ Found 902 matches in chunk 518
# ✅ Found 687 matches in chunk 519
# ✅ Found 732 matches in chunk 520
# ✅ Found 768 matches in chunk 521
# ✅ Found 771 matches in chunk 522
# ✅ Found 736 matches in chunk 523
# ✅ Found 876 matches in chunk 524
# ✅ Found 863 matches in chunk 525
# ✅ Found 711 matches in chunk 526
# ✅ Found 676 matches in chunk 527
# ✅ Found 685 matches in chunk 528
# ✅ Found 700 matches in chunk 529
# ✅ Found 792 matches in chunk 530
# ✅ Found 824 matches in chunk 531
# ✅ Found 767 matches in chunk 532
# ✅ Found 785 matches in chunk 533
# ✅ Found 776 matches in chunk 534
# ✅ Found 785 matches in chunk 535
# ✅ Found 818 matches in chunk 536
# ✅ Found 818 matches in chunk 537
# ✅ Found 819 matches in chunk 538
# ✅ Found 948 matches in chunk 539
# ✅ Found 876 matches in chunk 540
# ✅ Found 903 matches in chunk 541
# ✅ Found 785 matches in chunk 542
# ✅ Found 886 matches in chunk 543
# ✅ Found 776 matches in chunk 544
# ✅ Found 777 matches in chunk 545
# ✅ Found 743 matches in chunk 546
# ✅ Found 890 matches in chunk 547
# ✅ Found 797 matches in chunk 548
# ✅ Found 701 matches in chunk 549
# ✅ Found 787 matches in chunk 550
# ✅ Found 754 matches in chunk 551
# ✅ Found 844 matches in chunk 552
# ✅ Found 791 matches in chunk 553
# ✅ Found 641 matches in chunk 554
# ✅ Found 809 matches in chunk 555
# ✅ Found 825 matches in chunk 556
# ✅ Found 752 matches in chunk 557
# ✅ Found 803 matches in chunk 558
# ✅ Found 804 matches in chunk 559
# ✅ Found 840 matches in chunk 560
# ✅ Found 745 matches in chunk 561
# ✅ Found 997 matches in chunk 562
# ✅ Found 892 matches in chunk 563
# ✅ Found 736 matches in chunk 564
# ✅ Found 796 matches in chunk 565
# ✅ Found 776 matches in chunk 566
# ✅ Found 850 matches in chunk 567
# ✅ Found 777 matches in chunk 568
# ✅ Found 886 matches in chunk 569
# ✅ Found 707 matches in chunk 570
# ✅ Found 903 matches in chunk 571
# ✅ Found 704 matches in chunk 572
# ✅ Found 751 matches in chunk 573
# ✅ Found 1014 matches in chunk 574
# ✅ Found 789 matches in chunk 575
# ✅ Found 936 matches in chunk 576
# ✅ Found 728 matches in chunk 577
# ✅ Found 884 matches in chunk 578
# ✅ Found 833 matches in chunk 579
# ✅ Found 854 matches in chunk 580
# ✅ Found 782 matches in chunk 581
# ✅ Found 805 matches in chunk 582
# ✅ Found 643 matches in chunk 583
# ✅ Found 704 matches in chunk 584
# ✅ Found 953 matches in chunk 585
# ✅ Found 791 matches in chunk 586
# ✅ Found 688 matches in chunk 587
# ✅ Found 845 matches in chunk 588
# ✅ Found 815 matches in chunk 589
# ✅ Found 972 matches in chunk 590
# ✅ Found 1124 matches in chunk 591
# ✅ Found 1117 matches in chunk 592
# ✅ Found 1024 matches in chunk 593
# ✅ Found 995 matches in chunk 594
# ✅ Found 1179 matches in chunk 595
# ✅ Found 1094 matches in chunk 596
# ✅ Found 1082 matches in chunk 597
# ✅ Found 1213 matches in chunk 598
# ✅ Found 859 matches in chunk 599
# Tracks found in unclaimed dataset: 486720
# ✅ Excel file created: final_artist_unclaimed.xlsx

# %% [markdown]
# ## **Project Summary**
#
# This project successfully demonstrates:
#
# - Integration with the Spotify API to fetch complete artist catalogs.
# - Efficient handling of large datasets (7GB TSV) using chunk processing.
# - Accurate ISRC-based matching between artist tracks and unclaimed musical works.
# - Production of a clean, organized Excel workbook with all relevant outputs.
# - Scalable and reusable workflow suitable for any artist and large datasets.

# %% [markdown]
# <div style="text-align: center; font-size: 48px;">
#     🙏 THANK YOU! 🙏
# </div>
